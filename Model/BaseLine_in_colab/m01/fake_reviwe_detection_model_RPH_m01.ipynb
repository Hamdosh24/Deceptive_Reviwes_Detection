# %% [markdown]
# # Preprotion

# %%
import shutil
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import transformers
from sklearn.metrics import precision_score, recall_score, f1_score,\
 accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# data path
data_paths = {}
data_paths["H"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Hotel.xlsx' # hotel
data_paths["R"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Resturent.xlsx' # resturent
data_paths["P"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Prodect.xlsx' # prodect

target_list = ['Fake', 'Truthful']

# %%
b_tokenizer = transformers.AutoTokenizer.from_pretrained("/content/drive/MyDrive/Models/tokenizers-bert-base-arabertv2")

# %%
MAX_LEN = 265
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
EPOCHS = 4
LEARNING_RATE = 2.5e-05

# %% [markdown]
# # Build the Model

# %%
class AFRD(Dataset):
    def __init__(self, dataset, tokenizer, max_len):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.text = self.dataset["Text"]
        self.targets = self.dataset[target_list].values
        self.n_samples = self.dataset.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        review = str(self.text[index])
        review = " ".join(review.split())

        inputs = self.tokenizer.encode_plus(review,
                                            None,
                                            add_special_tokens=True,
                                            max_length=self.max_len,
                                            padding="max_length",
                                            truncation=True,
                                            return_attention_mask=True,
                                            return_tensors="pt"
                                            )

        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "token_type_ids": inputs["token_type_ids"].flatten(),
            "targets": torch.FloatTensor(np.array(self.targets[index])).flatten()
        }

# %%
class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = transformers.AutoModel.from_pretrained("/content/drive/MyDrive/Models/model-bert-base-arabertv2", return_dict=True)
        self.dropout = nn.Dropout(0.1)
        self.linear = nn.Linear(768, 2)

    def forward(self, input_ids, attention_mask, token_type_ids):
        output = self.bert_model(input_ids, attention_mask, token_type_ids)
        output_dropout = self.dropout(output["pooler_output"])
        output = self.linear(output_dropout)
        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /content/drive/MyDrive/Models/model-bert-base-arabertv2 and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (linear): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# # saving & loadding Function

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']

    return model, optimizer, checkpoint['epoch'], valid_loss_min.item()

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %% [markdown]
# # Loss Function & Optimizer

# %%
def loss_fn(output, target):
    return nn.BCEWithLogitsLoss()(output, target)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Training Function

# %%
def train_model(
        n_epochs,
        training_loader,
        validation_loader,
        model,
        optimizer,
        checkpoint_path,
        best_model_path
):
    train_loss_list = []
    valid_loss_list = []

    n_total_steps_train = len(training_loader)
    n_total_steps_valid = len(validation_loader)

    valid_loss_min = np.Inf

    for epoch in range(n_epochs):

        sum_train_loss = 0
        sum_valid_loss = 0
        train_loss = 0
        valid_loss = 0
        model.train()
        # train

        for index, batch in enumerate(training_loader):
            input_ids = batch["input_ids"].to(device, dtype=torch.long)
            attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
            targets = batch['targets'].to(device, dtype=torch.float)


            # forward pass
            output = model(input_ids, attention_mask, token_type_ids)

            optimizer.zero_grad()
            loss = loss_fn(output, targets)
            optimizer.zero_grad()

            # backward pass
            loss.backward()
            optimizer.step()

            train_loss = train_loss + (1/(index+1)*(loss.item()-train_loss))
            sum_train_loss += train_loss
            print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_train}, train_loss={train_loss:.4f}")
            # optimizer.zero_grad()

        # valid
        model.eval()
        with torch.no_grad():
            for index, batch in enumerate(validation_loader):
                input_ids = batch["input_ids"].to(device, dtype=torch.long)
                attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
                token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
                targets = batch['targets'].to(device, dtype=torch.float)
                output = model(input_ids, attention_mask, token_type_ids)

                loss = loss_fn(output, targets)
                valid_loss = valid_loss + (1 / (index + 1) * (loss.item() - valid_loss))
                sum_valid_loss += valid_loss
                print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_valid}, valid_loss={loss.item():.4f}")

        checkpoint = {
            "epoch": epoch + 1,
            "valid_loss_min": valid_loss,
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict()
        }

        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        train_loss_list.append(sum_train_loss/n_total_steps_train)
        valid_loss_list.append(sum_valid_loss/n_total_steps_valid)
    # Train & Valid loss Curve
    # Generate a sequence of integers to represent the epoch numbers
    epochs_r = list(range(1, n_epochs+1))
    print(train_loss_list)
    print(epochs_r)

    # Plot and label the training and validation loss values
    plt.plot(epochs_r, train_loss_list, label='Training Loss')
    plt.plot(epochs_r, valid_loss_list, label='Validation Loss')

    # Add in a title and axes labels
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Set the tick locations
    plt.xticks(range(1, n_epochs+1, 1))

    # Display the plot
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# # Test Function

# %%
def test_model(model, test_data):
  metrics_0 = {}
  metrics_1 = {}
  test_len = test_data.shape[0]
  text_test = test_data["Text"]
  targets_test = test_data[target_list].to_numpy().reshape(-1,2)
  del test_data
  targets_pred = []

  model.eval()
  with torch.no_grad():
    for review in text_test:
        review = str(review)
        emb = b_tokenizer.encode_plus(review,
                                      None,
                                      add_special_tokens=True,
                                      max_length=MAX_LEN,
                                      padding="max_length",
                                      truncation=True,
                                      return_attention_mask=True,
                                      return_tensors="pt"
                                      )

        input_ids = emb["input_ids"].to(device, dtype=torch.long)
        attention_mask = emb['attention_mask'].to(device, dtype=torch.long)
        token_type_ids = emb['token_type_ids'].to(device, dtype=torch.long)

        res = model(input_ids, attention_mask, token_type_ids)
        final_res = torch.sigmoid(res).cpu().detach().numpy()

        targets_pred.append(final_res)

  targets_pred = np.array(targets_pred).reshape(-1,2)
  targets_pred = np.apply_along_axis(max_class, 1, targets_pred)

  metrics_0["accuracy_score"] = accuracy_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["precision_score"] =  precision_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["recall_score"] = recall_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["f1_score"] =  f1_score(targets_test[:, 0], targets_pred[:, 0])

  metrics_1["accuracy_score"] = accuracy_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["precision_score"] =  precision_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["recall_score"] = recall_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["f1_score"] =  f1_score(targets_test[:, 1], targets_pred[:, 1])

  confusion_matrix_res = confusion_matrix(targets_test[:, 0], targets_pred[:, 0])

  cm_display = ConfusionMatrixDisplay(
      confusion_matrix=confusion_matrix_res,
      display_labels=[0, 1])

  print(f"metrics_0: {metrics_0}\n metrics_1: {metrics_1}")
  print(classification_report(targets_test[:, 0], targets_pred[:, 0], target_names=['Truthful', 'Fake']))
  cm_display.plot()
  plt.show()

# %%
def max_class(item):
  item = np.where(item == max(item), 1, 0)
  return item

# %% [markdown]
# # Multi data training/Testing

# %%
def pipeline(data_paths, model, optimizer, train_fn, test_fn):
  curr_stage = ''
  total_test = pd.DataFrame(columns=['Text', 'Fake', 'Truthful'])
  exe_seq = ["R", "P", "H"]
  for i in exe_seq:
    # import the data set
    data = pd.read_excel(data_paths[i])
    data.drop(labels=['Age', 'Gender','Platform/Name', 'Product', 'Rating', 'Polarity'], axis=1, inplace=True)
    target_list = ['Fake', 'Truthful']

    # encoding
    enc_y_data = pd.get_dummies(data['Class'], dtype=float)
    data[target_list] = enc_y_data[target_list]
    data.drop(labels=['Class'], axis=1, inplace=True)

    # splitting the data into train, valid, test
    train_data, test_data = train_test_split(data, test_size=0.25, random_state=32, shuffle=True)
    train_data, valid_data = train_test_split(train_data, test_size=0.2, random_state=32, shuffle=True,)

    train_data.reset_index(drop=True, inplace=True)
    valid_data.reset_index(drop=True, inplace=True)
    test_data.reset_index(drop=True, inplace=True)

    train_data = AFRD(train_data, b_tokenizer, MAX_LEN)
    valid_data = AFRD(valid_data, b_tokenizer, MAX_LEN)

    train_data_loader = DataLoader(
    train_data,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
    num_workers=0
    )

    val_data_loader = DataLoader(
    valid_data,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=0
    )
    del train_data, valid_data

    curr_stage = curr_stage + f"{i}"
    print(f'############################-{curr_stage}model-################################')
    # Training
    train_fn(EPOCHS, train_data_loader, val_data_loader, model, optimizer, f"./{curr_stage}_curr_ck.pt", f"./{curr_stage}_best.pt")
    # Testing
    test_fn(model, test_data)

    del train_data_loader, val_data_loader
    total_test = pd.concat([total_test, test_data], ignore_index=True)
    del test_data

  print('###############################-Final Test-#######################################')
  test_fn(model, total_test)

# %%
pipeline(data_paths, model, optimizer, train_model, test_model)
# Out:
# ############################-Rmodel-################################
# epoch 1/4, step 1/27, train_loss=0.6876
# epoch 1/4, step 2/27, train_loss=0.6847
# epoch 1/4, step 3/27, train_loss=0.6867
# epoch 1/4, step 4/27, train_loss=0.6913
# epoch 1/4, step 5/27, train_loss=0.6797
# epoch 1/4, step 6/27, train_loss=0.6849
# epoch 1/4, step 7/27, train_loss=0.6814
# epoch 1/4, step 8/27, train_loss=0.6780
# epoch 1/4, step 9/27, train_loss=0.6724
# epoch 1/4, step 10/27, train_loss=0.6644
# epoch 1/4, step 11/27, train_loss=0.6585
# epoch 1/4, step 12/27, train_loss=0.6549
# epoch 1/4, step 13/27, train_loss=0.6570
# epoch 1/4, step 14/27, train_loss=0.6513
# epoch 1/4, step 15/27, train_loss=0.6460
# epoch 1/4, step 16/27, train_loss=0.6385
# epoch 1/4, step 17/27, train_loss=0.6351
# epoch 1/4, step 18/27, train_loss=0.6376
# epoch 1/4, step 19/27, train_loss=0.6319
# epoch 1/4, step 20/27, train_loss=0.6280
# epoch 1/4, step 21/27, train_loss=0.6266
# epoch 1/4, step 22/27, train_loss=0.6249
# epoch 1/4, step 23/27, train_loss=0.6234
# epoch 1/4, step 24/27, train_loss=0.6237
# epoch 1/4, step 25/27, train_loss=0.6182
# epoch 1/4, step 26/27, train_loss=0.6221
# epoch 1/4, step 27/27, train_loss=0.6202
# epoch 1/4, step 1/7, valid_loss=0.5151
# epoch 1/4, step 2/7, valid_loss=0.4128
# epoch 1/4, step 3/7, valid_loss=0.5503
# epoch 1/4, step 4/7, valid_loss=0.5397
# epoch 1/4, step 5/7, valid_loss=0.5426
# epoch 1/4, step 6/7, valid_loss=0.6986
# epoch 1/4, step 7/7, valid_loss=0.5355
# epoch 2/4, step 1/27, train_loss=0.4226
# epoch 2/4, step 2/27, train_loss=0.3804
# epoch 2/4, step 3/27, train_loss=0.3996
# epoch 2/4, step 4/27, train_loss=0.4052
# epoch 2/4, step 5/27, train_loss=0.4008
# epoch 2/4, step 6/27, train_loss=0.4054
# epoch 2/4, step 7/27, train_loss=0.4396
# epoch 2/4, step 8/27, train_loss=0.4394
# epoch 2/4, step 9/27, train_loss=0.4201
# epoch 2/4, step 10/27, train_loss=0.4266
# epoch 2/4, step 11/27, train_loss=0.4407
# epoch 2/4, step 12/27, train_loss=0.4399
# epoch 2/4, step 13/27, train_loss=0.4240
# epoch 2/4, step 14/27, train_loss=0.4270
# epoch 2/4, step 15/27, train_loss=0.4356
# epoch 2/4, step 16/27, train_loss=0.4322
# epoch 2/4, step 17/27, train_loss=0.4416
# epoch 2/4, step 18/27, train_loss=0.4386
# epoch 2/4, step 19/27, train_loss=0.4344
# epoch 2/4, step 20/27, train_loss=0.4267
# epoch 2/4, step 21/27, train_loss=0.4260
# epoch 2/4, step 22/27, train_loss=0.4214
# epoch 2/4, step 23/27, train_loss=0.4208
# epoch 2/4, step 24/27, train_loss=0.4246
# epoch 2/4, step 25/27, train_loss=0.4237
# epoch 2/4, step 26/27, train_loss=0.4206
# epoch 2/4, step 27/27, train_loss=0.4114
# epoch 2/4, step 1/7, valid_loss=0.3601
# epoch 2/4, step 2/7, valid_loss=0.3210
# epoch 2/4, step 3/7, valid_loss=0.3632
# epoch 2/4, step 4/7, valid_loss=0.3778
# epoch 2/4, step 5/7, valid_loss=0.4133
# epoch 2/4, step 6/7, valid_loss=0.4920
# epoch 2/4, step 7/7, valid_loss=0.3637
# epoch 3/4, step 1/27, train_loss=0.2028
# epoch 3/4, step 2/27, train_loss=0.2228
# epoch 3/4, step 3/27, train_loss=0.2140
# epoch 3/4, step 4/27, train_loss=0.2353
# epoch 3/4, step 5/27, train_loss=0.2215
# epoch 3/4, step 6/27, train_loss=0.2057
# epoch 3/4, step 7/27, train_loss=0.2236
# epoch 3/4, step 8/27, train_loss=0.2238
# epoch 3/4, step 9/27, train_loss=0.2421
# epoch 3/4, step 10/27, train_loss=0.2580
# epoch 3/4, step 11/27, train_loss=0.2482
# epoch 3/4, step 12/27, train_loss=0.2665
# epoch 3/4, step 13/27, train_loss=0.2779
# epoch 3/4, step 14/27, train_loss=0.2798
# epoch 3/4, step 15/27, train_loss=0.2818
# epoch 3/4, step 16/27, train_loss=0.2778
# epoch 3/4, step 17/27, train_loss=0.2671
# epoch 3/4, step 18/27, train_loss=0.2669
# epoch 3/4, step 19/27, train_loss=0.2672
# epoch 3/4, step 20/27, train_loss=0.2685
# epoch 3/4, step 21/27, train_loss=0.2697
# epoch 3/4, step 22/27, train_loss=0.2678
# epoch 3/4, step 23/27, train_loss=0.2710
# epoch 3/4, step 24/27, train_loss=0.2688
# epoch 3/4, step 25/27, train_loss=0.2770
# epoch 3/4, step 26/27, train_loss=0.2722
# epoch 3/4, step 27/27, train_loss=0.2727
# epoch 3/4, step 1/7, valid_loss=0.7316
# epoch 3/4, step 2/7, valid_loss=0.4702
# epoch 3/4, step 3/7, valid_loss=0.1926
# epoch 3/4, step 4/7, valid_loss=0.3073
# epoch 3/4, step 5/7, valid_loss=0.7306
# epoch 3/4, step 6/7, valid_loss=0.2235
# epoch 3/4, step 7/7, valid_loss=0.6970
# epoch 4/4, step 1/27, train_loss=0.3931
# epoch 4/4, step 2/27, train_loss=0.3993
# epoch 4/4, step 3/27, train_loss=0.3325
# epoch 4/4, step 4/27, train_loss=0.2695
# epoch 4/4, step 5/27, train_loss=0.2314
# epoch 4/4, step 6/27, train_loss=0.2115
# epoch 4/4, step 7/27, train_loss=0.2242
# epoch 4/4, step 8/27, train_loss=0.2216
# epoch 4/4, step 9/27, train_loss=0.2487
# epoch 4/4, step 10/27, train_loss=0.2345
# epoch 4/4, step 11/27, train_loss=0.2341
# epoch 4/4, step 12/27, train_loss=0.2293
# epoch 4/4, step 13/27, train_loss=0.2226
# epoch 4/4, step 14/27, train_loss=0.2145
# epoch 4/4, step 15/27, train_loss=0.2050
# epoch 4/4, step 16/27, train_loss=0.2027
# epoch 4/4, step 17/27, train_loss=0.1940
# epoch 4/4, step 18/27, train_loss=0.1918
# epoch 4/4, step 19/27, train_loss=0.1912
# epoch 4/4, step 20/27, train_loss=0.1860
# epoch 4/4, step 21/27, train_loss=0.1879
# epoch 4/4, step 22/27, train_loss=0.1825
# epoch 4/4, step 23/27, train_loss=0.1853
# epoch 4/4, step 24/27, train_loss=0.1889
# epoch 4/4, step 25/27, train_loss=0.1903
# epoch 4/4, step 26/27, train_loss=0.1936
# epoch 4/4, step 27/27, train_loss=0.2031
# epoch 4/4, step 1/7, valid_loss=0.2971
# epoch 4/4, step 2/7, valid_loss=0.3502
# epoch 4/4, step 3/7, valid_loss=0.1501
# epoch 4/4, step 4/7, valid_loss=0.3136
# epoch 4/4, step 5/7, valid_loss=0.2596
# epoch 4/4, step 6/7, valid_loss=0.6861
# epoch 4/4, step 7/7, valid_loss=0.3672
# [0.6521791610716541, 0.42329075382355097, 0.2537181258817539, 0.2284787416184233]
# [1, 2, 3, 4]
# metrics_0: {'accuracy_score': 0.8156424581005587, 'precision_score': 0.8461538461538461, 'recall_score': 0.8020833333333334, 'f1_score': 0.823529411764706}
#  metrics_1: {'accuracy_score': 0.8156424581005587, 'precision_score': 0.7840909090909091, 'recall_score': 0.8313253012048193, 'f1_score': 0.8070175438596491}
#               precision    recall  f1-score   support
#
#     Truthful       0.78      0.83      0.81        83
#         Fake       0.85      0.80      0.82        96
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.82      0.82       179
# weighted avg       0.82      0.82      0.82       179
# ############################-RPmodel-################################
# epoch 1/4, step 1/27, train_loss=0.9906
# epoch 1/4, step 2/27, train_loss=0.8531
# epoch 1/4, step 3/27, train_loss=1.0418
# epoch 1/4, step 4/27, train_loss=0.9356
# epoch 1/4, step 5/27, train_loss=0.8510
# epoch 1/4, step 6/27, train_loss=0.7555
# epoch 1/4, step 7/27, train_loss=0.7090
# epoch 1/4, step 8/27, train_loss=0.6672
# epoch 1/4, step 9/27, train_loss=0.6636
# epoch 1/4, step 10/27, train_loss=0.6689
# epoch 1/4, step 11/27, train_loss=0.6718
# epoch 1/4, step 12/27, train_loss=0.6529
# epoch 1/4, step 13/27, train_loss=0.6343
# epoch 1/4, step 14/27, train_loss=0.6256
# epoch 1/4, step 15/27, train_loss=0.6135
# epoch 1/4, step 16/27, train_loss=0.6040
# epoch 1/4, step 17/27, train_loss=0.5956
# epoch 1/4, step 18/27, train_loss=0.5953
# epoch 1/4, step 19/27, train_loss=0.5986
# epoch 1/4, step 20/27, train_loss=0.5994
# epoch 1/4, step 21/27, train_loss=0.5869
# epoch 1/4, step 22/27, train_loss=0.5838
# epoch 1/4, step 23/27, train_loss=0.5811
# epoch 1/4, step 24/27, train_loss=0.5762
# epoch 1/4, step 25/27, train_loss=0.5680
# epoch 1/4, step 26/27, train_loss=0.5702
# epoch 1/4, step 27/27, train_loss=0.5650
# epoch 1/4, step 1/7, valid_loss=0.5492
# epoch 1/4, step 2/7, valid_loss=0.6124
# epoch 1/4, step 3/7, valid_loss=0.3454
# epoch 1/4, step 4/7, valid_loss=0.5356
# epoch 1/4, step 5/7, valid_loss=0.5662
# epoch 1/4, step 6/7, valid_loss=0.5296
# epoch 1/4, step 7/7, valid_loss=0.2918
# epoch 2/4, step 1/27, train_loss=0.4649
# epoch 2/4, step 2/27, train_loss=0.4251
# epoch 2/4, step 3/27, train_loss=0.3972
# epoch 2/4, step 4/27, train_loss=0.3832
# epoch 2/4, step 5/27, train_loss=0.3453
# epoch 2/4, step 6/27, train_loss=0.3328
# epoch 2/4, step 7/27, train_loss=0.3334
# epoch 2/4, step 8/27, train_loss=0.3610
# epoch 2/4, step 9/27, train_loss=0.3627
# epoch 2/4, step 10/27, train_loss=0.4003
# epoch 2/4, step 11/27, train_loss=0.4120
# epoch 2/4, step 12/27, train_loss=0.4102
# epoch 2/4, step 13/27, train_loss=0.4195
# epoch 2/4, step 14/27, train_loss=0.4125
# epoch 2/4, step 15/27, train_loss=0.4012
# epoch 2/4, step 16/27, train_loss=0.3995
# epoch 2/4, step 17/27, train_loss=0.4010
# epoch 2/4, step 18/27, train_loss=0.4084
# epoch 2/4, step 19/27, train_loss=0.3938
# epoch 2/4, step 20/27, train_loss=0.3885
# epoch 2/4, step 21/27, train_loss=0.3750
# epoch 2/4, step 22/27, train_loss=0.3770
# epoch 2/4, step 23/27, train_loss=0.3829
# epoch 2/4, step 24/27, train_loss=0.3832
# epoch 2/4, step 25/27, train_loss=0.3744
# epoch 2/4, step 26/27, train_loss=0.3767
# epoch 2/4, step 27/27, train_loss=0.3959
# epoch 2/4, step 1/7, valid_loss=0.4973
# epoch 2/4, step 2/7, valid_loss=0.8325
# epoch 2/4, step 3/7, valid_loss=0.2063
# epoch 2/4, step 4/7, valid_loss=0.5304
# epoch 2/4, step 5/7, valid_loss=0.6569
# epoch 2/4, step 6/7, valid_loss=0.4468
# epoch 2/4, step 7/7, valid_loss=0.1823
# epoch 3/4, step 1/27, train_loss=0.3714
# epoch 3/4, step 2/27, train_loss=0.3291
# epoch 3/4, step 3/27, train_loss=0.3054
# epoch 3/4, step 4/27, train_loss=0.2725
# epoch 3/4, step 5/27, train_loss=0.2864
# epoch 3/4, step 6/27, train_loss=0.2984
# epoch 3/4, step 7/27, train_loss=0.2744
# epoch 3/4, step 8/27, train_loss=0.2587
# epoch 3/4, step 9/27, train_loss=0.2605
# epoch 3/4, step 10/27, train_loss=0.2532
# epoch 3/4, step 11/27, train_loss=0.2760
# epoch 3/4, step 12/27, train_loss=0.2785
# epoch 3/4, step 13/27, train_loss=0.3023
# epoch 3/4, step 14/27, train_loss=0.3130
# epoch 3/4, step 15/27, train_loss=0.2993
# epoch 3/4, step 16/27, train_loss=0.3055
# epoch 3/4, step 17/27, train_loss=0.3031
# epoch 3/4, step 18/27, train_loss=0.2984
# epoch 3/4, step 19/27, train_loss=0.2941
# epoch 3/4, step 20/27, train_loss=0.2878
# epoch 3/4, step 21/27, train_loss=0.2847
# epoch 3/4, step 22/27, train_loss=0.2840
# epoch 3/4, step 23/27, train_loss=0.2753
# epoch 3/4, step 24/27, train_loss=0.2766
# epoch 3/4, step 25/27, train_loss=0.2701
# epoch 3/4, step 26/27, train_loss=0.2676
# epoch 3/4, step 27/27, train_loss=0.2601
# epoch 3/4, step 1/7, valid_loss=0.3958
# epoch 3/4, step 2/7, valid_loss=0.7891
# epoch 3/4, step 3/7, valid_loss=0.1648
# epoch 3/4, step 4/7, valid_loss=0.5681
# epoch 3/4, step 5/7, valid_loss=0.6422
# epoch 3/4, step 6/7, valid_loss=0.5296
# epoch 3/4, step 7/7, valid_loss=0.1501
# epoch 4/4, step 1/27, train_loss=0.2502
# epoch 4/4, step 2/27, train_loss=0.2643
# epoch 4/4, step 3/27, train_loss=0.2121
# epoch 4/4, step 4/27, train_loss=0.1797
# epoch 4/4, step 5/27, train_loss=0.1606
# epoch 4/4, step 6/27, train_loss=0.1818
# epoch 4/4, step 7/27, train_loss=0.1685
# epoch 4/4, step 8/27, train_loss=0.1582
# epoch 4/4, step 9/27, train_loss=0.1660
# epoch 4/4, step 10/27, train_loss=0.1584
# epoch 4/4, step 11/27, train_loss=0.1622
# epoch 4/4, step 12/27, train_loss=0.1529
# epoch 4/4, step 13/27, train_loss=0.1496
# epoch 4/4, step 14/27, train_loss=0.1422
# epoch 4/4, step 15/27, train_loss=0.1357
# epoch 4/4, step 16/27, train_loss=0.1469
# epoch 4/4, step 17/27, train_loss=0.1403
# epoch 4/4, step 18/27, train_loss=0.1375
# epoch 4/4, step 19/27, train_loss=0.1379
# epoch 4/4, step 20/27, train_loss=0.1327
# epoch 4/4, step 21/27, train_loss=0.1357
# epoch 4/4, step 22/27, train_loss=0.1376
# epoch 4/4, step 23/27, train_loss=0.1332
# epoch 4/4, step 24/27, train_loss=0.1303
# epoch 4/4, step 25/27, train_loss=0.1287
# epoch 4/4, step 26/27, train_loss=0.1325
# epoch 4/4, step 27/27, train_loss=0.1285
# epoch 4/4, step 1/7, valid_loss=0.4147
# epoch 4/4, step 2/7, valid_loss=0.6437
# epoch 4/4, step 3/7, valid_loss=0.3231
# epoch 4/4, step 4/7, valid_loss=0.6367
# epoch 4/4, step 5/7, valid_loss=0.6635
# epoch 4/4, step 6/7, valid_loss=0.7543
# epoch 4/4, step 7/7, valid_loss=0.0512
# [0.6799448460442948, 0.3895307893103203, 0.2883833986984252, 0.15792730434145946]
# [1, 2, 3, 4]
# metrics_0: {'accuracy_score': 0.75, 'precision_score': 0.8, 'recall_score': 0.6956521739130435, 'f1_score': 0.7441860465116279}
#  metrics_1: {'accuracy_score': 0.75, 'precision_score': 0.7083333333333334, 'recall_score': 0.8095238095238095, 'f1_score': 0.7555555555555556}
#               precision    recall  f1-score   support
#
#     Truthful       0.71      0.81      0.76        84
#         Fake       0.80      0.70      0.74        92
#
#     accuracy                           0.75       176
#    macro avg       0.75      0.75      0.75       176
# weighted avg       0.76      0.75      0.75       176
# ############################-RPHmodel-################################
# epoch 1/4, step 1/12, train_loss=0.7591
# epoch 1/4, step 2/12, train_loss=0.7097
# epoch 1/4, step 3/12, train_loss=0.5125
# epoch 1/4, step 4/12, train_loss=0.5457
# epoch 1/4, step 5/12, train_loss=0.4424
# epoch 1/4, step 6/12, train_loss=0.5054
# epoch 1/4, step 7/12, train_loss=0.5492
# epoch 1/4, step 8/12, train_loss=0.5616
# epoch 1/4, step 9/12, train_loss=0.5517
# epoch 1/4, step 10/12, train_loss=0.5411
# epoch 1/4, step 11/12, train_loss=0.5484
# epoch 1/4, step 12/12, train_loss=0.5587
# epoch 1/4, step 1/3, valid_loss=0.3014
# epoch 1/4, step 2/3, valid_loss=0.8061
# epoch 1/4, step 3/3, valid_loss=0.2368
# epoch 2/4, step 1/12, train_loss=0.5496
# epoch 2/4, step 2/12, train_loss=0.3291
# epoch 2/4, step 3/12, train_loss=0.3122
# epoch 2/4, step 4/12, train_loss=0.2698
# epoch 2/4, step 5/12, train_loss=0.2885
# epoch 2/4, step 6/12, train_loss=0.3052
# epoch 2/4, step 7/12, train_loss=0.2957
# epoch 2/4, step 8/12, train_loss=0.2960
# epoch 2/4, step 9/12, train_loss=0.2888
# epoch 2/4, step 10/12, train_loss=0.3001
# epoch 2/4, step 11/12, train_loss=0.2930
# epoch 2/4, step 12/12, train_loss=0.3009
# epoch 2/4, step 1/3, valid_loss=0.2742
# epoch 2/4, step 2/3, valid_loss=0.6870
# epoch 2/4, step 3/3, valid_loss=0.1528
# epoch 3/4, step 1/12, train_loss=0.1598
# epoch 3/4, step 2/12, train_loss=0.1351
# epoch 3/4, step 3/12, train_loss=0.2131
# epoch 3/4, step 4/12, train_loss=0.2542
# epoch 3/4, step 5/12, train_loss=0.2612
# epoch 3/4, step 6/12, train_loss=0.2339
# epoch 3/4, step 7/12, train_loss=0.2262
# epoch 3/4, step 8/12, train_loss=0.2141
# epoch 3/4, step 9/12, train_loss=0.2175
# epoch 3/4, step 10/12, train_loss=0.2033
# epoch 3/4, step 11/12, train_loss=0.1913
# epoch 3/4, step 12/12, train_loss=0.1802
# epoch 3/4, step 1/3, valid_loss=0.4312
# epoch 3/4, step 2/3, valid_loss=0.2726
# epoch 3/4, step 3/3, valid_loss=0.3144
# epoch 4/4, step 1/12, train_loss=0.1896
# epoch 4/4, step 2/12, train_loss=0.2596
# epoch 4/4, step 3/12, train_loss=0.1983
# epoch 4/4, step 4/12, train_loss=0.1622
# epoch 4/4, step 5/12, train_loss=0.1697
# epoch 4/4, step 6/12, train_loss=0.1642
# epoch 4/4, step 7/12, train_loss=0.1585
# epoch 4/4, step 8/12, train_loss=0.1436
# epoch 4/4, step 9/12, train_loss=0.1395
# epoch 4/4, step 10/12, train_loss=0.1335
# epoch 4/4, step 11/12, train_loss=0.1247
# epoch 4/4, step 12/12, train_loss=0.1184
# epoch 4/4, step 1/3, valid_loss=0.2536
# epoch 4/4, step 2/3, valid_loss=0.7601
# epoch 4/4, step 3/3, valid_loss=0.1132
# [0.5654533913984575, 0.3190790701595042, 0.2075074436559202, 0.16348792528230768]
# [1, 2, 3, 4]
# metrics_0: {'accuracy_score': 0.8717948717948718, 'precision_score': 0.8529411764705882, 'recall_score': 0.8529411764705882, 'f1_score': 0.8529411764705882}
#  metrics_1: {'accuracy_score': 0.8717948717948718, 'precision_score': 0.8863636363636364, 'recall_score': 0.8863636363636364, 'f1_score': 0.8863636363636365}
#               precision    recall  f1-score   support
#
#     Truthful       0.89      0.89      0.89        44
#         Fake       0.85      0.85      0.85        34
#
#     accuracy                           0.87        78
#    macro avg       0.87      0.87      0.87        78
# weighted avg       0.87      0.87      0.87        78
# ###############################-Final Test-#######################################
# metrics_0: {'accuracy_score': 0.7182448036951501, 'precision_score': 0.9032258064516129, 'recall_score': 0.5045045045045045, 'f1_score': 0.6473988439306358}
#  metrics_1: {'accuracy_score': 0.7182448036951501, 'precision_score': 0.6440129449838188, 'recall_score': 0.943127962085308, 'f1_score': 0.7653846153846154}
#               precision    recall  f1-score   support
#
#     Truthful       0.64      0.94      0.77       211
#         Fake       0.90      0.50      0.65       222
#
#     accuracy                           0.72       433
#    macro avg       0.77      0.72      0.71       433
# weighted avg       0.78      0.72      0.70       433

# %% [markdown]
# # Exit

# %%
exit()

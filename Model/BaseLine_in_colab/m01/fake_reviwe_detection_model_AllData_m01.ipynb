# %% [markdown]
# # Preprotion

# %%
import shutil
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import transformers
from sklearn.metrics import precision_score, recall_score, f1_score,\
 accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Bulding the model

# %%
data_paths = {}
data_paths["H"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Hotel.xlsx' # hotel
data_paths["R"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Resturent.xlsx' # resturent
data_paths["P"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Prodect.xlsx' # prodect

h_data = pd.read_excel(data_paths['H'])
r_data = pd.read_excel(data_paths['R'])
p_data = pd.read_excel(data_paths['P'])

data = pd.concat([h_data, r_data], ignore_index=True)
data = pd.concat([data, p_data], ignore_index=True)

del data_paths, h_data, r_data, p_data

data.drop(labels=['Age', 'Gender','Platform/Name', 'Product', 'Rating', 'Polarity'], axis=1, inplace=True)
target_list = ['Fake', 'Truthful']

enc_y_data = pd.get_dummies(data['Class'], dtype=float)
data[target_list] = enc_y_data[target_list]
data.drop(labels=['Class'], axis=1, inplace=True)

# %%
train_data, test_data = train_test_split(data, test_size=0.25, random_state=32, shuffle=True)

# %%
MAX_LEN = 265
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
EPOCHS = 3
LEARNING_RATE = 2.5e-05

# %%
b_tokenizer = transformers.AutoTokenizer.from_pretrained("/content/drive/MyDrive/Models/tokenizers-bert-base-arabertv2")

# %%
class AFRD(Dataset):
    def __init__(self, dataset, tokenizer, max_len):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.text = self.dataset["Text"]
        self.targets = self.dataset[target_list].values
        self.n_samples = self.dataset.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        review = str(self.text[index])
        review = " ".join(review.split())

        inputs = self.tokenizer.encode_plus(review,
                                            None,
                                            add_special_tokens=True,
                                            max_length=self.max_len,
                                            padding="max_length",
                                            truncation=True,
                                            return_attention_mask=True,
                                            return_tensors="pt"
                                            )

        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "token_type_ids": inputs["token_type_ids"].flatten(),
            "targets": torch.FloatTensor(np.array(self.targets[index])).flatten()
        }

# %%
train_data, valid_data = train_test_split(train_data, test_size=0.2, random_state=32, shuffle=True,)

train_data.reset_index(drop=True, inplace=True)
valid_data.reset_index(drop=True, inplace=True)

train_set = AFRD(train_data, b_tokenizer, MAX_LEN)
valid_set = AFRD(valid_data, b_tokenizer, MAX_LEN)

# %%
train_data_loader = DataLoader(
    train_set,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
    num_workers=0
)

val_data_loader = DataLoader(
    valid_set,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=0
)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']

    return model, optimizer, checkpoint['epoch'], valid_loss_min.item()

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %%
class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = transformers.AutoModel.from_pretrained("/content/drive/MyDrive/Models/model-bert-base-arabertv2", return_dict=True)
        self.dropout = nn.Dropout(0.1)
        self.linear = nn.Linear(768, 2)

    def forward(self, input_ids, attention_mask, token_type_ids):
        output = self.bert_model(input_ids, attention_mask, token_type_ids)
        output_dropout = self.dropout(output["pooler_output"])
        output = self.linear(output_dropout)
        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /content/drive/MyDrive/Models/model-bert-base-arabertv2 and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (linear): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
def loss_fn(output, target):
    return nn.BCEWithLogitsLoss()(output, target)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Trainning

# %%
def train_model(
        n_epochs,
        training_loader,
        validation_loader,
        model,
        optimizer,
        checkpoint_path,
        best_model_path
):
    train_loss_list = []
    valid_loss_list = []

    n_total_steps_train = len(training_loader)
    n_total_steps_valid = len(validation_loader)

    valid_loss_min = np.Inf

    for epoch in range(n_epochs):

        sum_train_loss = 0
        sum_valid_loss = 0
        train_loss = 0
        valid_loss = 0
        model.train()
        # train

        for index, batch in enumerate(training_loader):
            input_ids = batch["input_ids"].to(device, dtype=torch.long)
            attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
            targets = batch['targets'].to(device, dtype=torch.float)


            # forward pass
            output = model(input_ids, attention_mask, token_type_ids)

            optimizer.zero_grad()
            loss = loss_fn(output, targets)
            optimizer.zero_grad()

            # backward pass
            loss.backward()
            optimizer.step()

            train_loss = train_loss + (1/(index+1)*(loss.item()-train_loss))
            sum_train_loss += train_loss
            print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_train}, train_loss={train_loss:.4f}")
            # optimizer.zero_grad()

        # valid
        model.eval()
        with torch.no_grad():
            for index, batch in enumerate(validation_loader):
                input_ids = batch["input_ids"].to(device, dtype=torch.long)
                attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
                token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
                targets = batch['targets'].to(device, dtype=torch.float)
                output = model(input_ids, attention_mask, token_type_ids)

                loss = loss_fn(output, targets)
                valid_loss = valid_loss + (1 / (index + 1) * (loss.item() - valid_loss))
                sum_valid_loss += valid_loss
                print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_valid}, valid_loss={loss.item():.4f}")

        checkpoint = {
            "epoch": epoch + 1,
            "valid_loss_min": valid_loss,
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict()
        }

        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        train_loss_list.append(sum_train_loss/n_total_steps_train)
        valid_loss_list.append(sum_valid_loss/n_total_steps_valid)
    # Train & Valid loss Curve
    # Generate a sequence of integers to represent the epoch numbers
    epochs_r = list(range(1, n_epochs+1))
    print(train_loss_list)
    print(epochs_r)

    # Plot and label the training and validation loss values
    plt.plot(epochs_r, train_loss_list, label='Training Loss')
    plt.plot(epochs_r, valid_loss_list, label='Validation Loss')

    # Add in a title and axes labels
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Set the tick locations
    plt.xticks(range(1, n_epochs+1, 1))

    # Display the plot
    plt.legend(loc='best')
    plt.show()

    return model

# %%
trained_model = train_model(EPOCHS, train_data_loader, val_data_loader, model, optimizer, "./curr_ckpt", "./best.pt")
# Out:
# epoch 1/3, step 1/65, train_loss=0.7018
# epoch 1/3, step 2/65, train_loss=0.7012
# epoch 1/3, step 3/65, train_loss=0.6972
# epoch 1/3, step 4/65, train_loss=0.6821
# epoch 1/3, step 5/65, train_loss=0.6817
# epoch 1/3, step 6/65, train_loss=0.6830
# epoch 1/3, step 7/65, train_loss=0.6825
# epoch 1/3, step 8/65, train_loss=0.6800
# epoch 1/3, step 9/65, train_loss=0.6808
# epoch 1/3, step 10/65, train_loss=0.6810
# epoch 1/3, step 11/65, train_loss=0.6778
# epoch 1/3, step 12/65, train_loss=0.6765
# epoch 1/3, step 13/65, train_loss=0.6718
# epoch 1/3, step 14/65, train_loss=0.6754
# epoch 1/3, step 15/65, train_loss=0.6745
# epoch 1/3, step 16/65, train_loss=0.6749
# epoch 1/3, step 17/65, train_loss=0.6703
# epoch 1/3, step 18/65, train_loss=0.6669
# epoch 1/3, step 19/65, train_loss=0.6659
# epoch 1/3, step 20/65, train_loss=0.6625
# epoch 1/3, step 21/65, train_loss=0.6633
# epoch 1/3, step 22/65, train_loss=0.6619
# epoch 1/3, step 23/65, train_loss=0.6596
# epoch 1/3, step 24/65, train_loss=0.6550
# epoch 1/3, step 25/65, train_loss=0.6545
# epoch 1/3, step 26/65, train_loss=0.6532
# epoch 1/3, step 27/65, train_loss=0.6512
# epoch 1/3, step 28/65, train_loss=0.6466
# epoch 1/3, step 29/65, train_loss=0.6473
# epoch 1/3, step 30/65, train_loss=0.6499
# epoch 1/3, step 31/65, train_loss=0.6512
# epoch 1/3, step 32/65, train_loss=0.6484
# epoch 1/3, step 33/65, train_loss=0.6450
# epoch 1/3, step 34/65, train_loss=0.6448
# epoch 1/3, step 35/65, train_loss=0.6442
# epoch 1/3, step 36/65, train_loss=0.6455
# epoch 1/3, step 37/65, train_loss=0.6458
# epoch 1/3, step 38/65, train_loss=0.6480
# epoch 1/3, step 39/65, train_loss=0.6466
# epoch 1/3, step 40/65, train_loss=0.6477
# epoch 1/3, step 41/65, train_loss=0.6473
# epoch 1/3, step 42/65, train_loss=0.6467
# epoch 1/3, step 43/65, train_loss=0.6458
# epoch 1/3, step 44/65, train_loss=0.6442
# epoch 1/3, step 45/65, train_loss=0.6421
# epoch 1/3, step 46/65, train_loss=0.6400
# epoch 1/3, step 47/65, train_loss=0.6384
# epoch 1/3, step 48/65, train_loss=0.6377
# epoch 1/3, step 49/65, train_loss=0.6352
# epoch 1/3, step 50/65, train_loss=0.6332
# epoch 1/3, step 51/65, train_loss=0.6292
# epoch 1/3, step 52/65, train_loss=0.6294
# epoch 1/3, step 53/65, train_loss=0.6274
# epoch 1/3, step 54/65, train_loss=0.6281
# epoch 1/3, step 55/65, train_loss=0.6267
# epoch 1/3, step 56/65, train_loss=0.6243
# epoch 1/3, step 57/65, train_loss=0.6247
# epoch 1/3, step 58/65, train_loss=0.6225
# epoch 1/3, step 59/65, train_loss=0.6230
# epoch 1/3, step 60/65, train_loss=0.6247
# epoch 1/3, step 61/65, train_loss=0.6230
# epoch 1/3, step 62/65, train_loss=0.6214
# epoch 1/3, step 63/65, train_loss=0.6201
# epoch 1/3, step 64/65, train_loss=0.6193
# epoch 1/3, step 65/65, train_loss=0.6197
# epoch 1/3, step 1/17, valid_loss=0.6381
# epoch 1/3, step 2/17, valid_loss=0.5719
# epoch 1/3, step 3/17, valid_loss=0.4625
# epoch 1/3, step 4/17, valid_loss=0.5479
# epoch 1/3, step 5/17, valid_loss=0.5902
# epoch 1/3, step 6/17, valid_loss=0.5270
# epoch 1/3, step 7/17, valid_loss=0.7144
# epoch 1/3, step 8/17, valid_loss=0.3771
# epoch 1/3, step 9/17, valid_loss=0.6544
# epoch 1/3, step 10/17, valid_loss=0.4120
# epoch 1/3, step 11/17, valid_loss=0.5263
# epoch 1/3, step 12/17, valid_loss=0.5430
# epoch 1/3, step 13/17, valid_loss=0.4495
# epoch 1/3, step 14/17, valid_loss=0.5746
# epoch 1/3, step 15/17, valid_loss=0.6767
# epoch 1/3, step 16/17, valid_loss=0.5372
# epoch 1/3, step 17/17, valid_loss=0.2441
# epoch 2/3, step 1/65, train_loss=0.5473
# epoch 2/3, step 2/65, train_loss=0.4642
# epoch 2/3, step 3/65, train_loss=0.5118
# epoch 2/3, step 4/65, train_loss=0.4803
# epoch 2/3, step 5/65, train_loss=0.4787
# epoch 2/3, step 6/65, train_loss=0.4538
# epoch 2/3, step 7/65, train_loss=0.4722
# epoch 2/3, step 8/65, train_loss=0.4705
# epoch 2/3, step 9/65, train_loss=0.4640
# epoch 2/3, step 10/65, train_loss=0.4606
# epoch 2/3, step 11/65, train_loss=0.4549
# epoch 2/3, step 12/65, train_loss=0.4603
# epoch 2/3, step 13/65, train_loss=0.4586
# epoch 2/3, step 14/65, train_loss=0.4540
# epoch 2/3, step 15/65, train_loss=0.4651
# epoch 2/3, step 16/65, train_loss=0.4644
# epoch 2/3, step 17/65, train_loss=0.4608
# epoch 2/3, step 18/65, train_loss=0.4624
# epoch 2/3, step 19/65, train_loss=0.4580
# epoch 2/3, step 20/65, train_loss=0.4524
# epoch 2/3, step 21/65, train_loss=0.4572
# epoch 2/3, step 22/65, train_loss=0.4574
# epoch 2/3, step 23/65, train_loss=0.4615
# epoch 2/3, step 24/65, train_loss=0.4759
# epoch 2/3, step 25/65, train_loss=0.4838
# epoch 2/3, step 26/65, train_loss=0.4836
# epoch 2/3, step 27/65, train_loss=0.4783
# epoch 2/3, step 28/65, train_loss=0.4780
# epoch 2/3, step 29/65, train_loss=0.4781
# epoch 2/3, step 30/65, train_loss=0.4796
# epoch 2/3, step 31/65, train_loss=0.4825
# epoch 2/3, step 32/65, train_loss=0.4875
# epoch 2/3, step 33/65, train_loss=0.4888
# epoch 2/3, step 34/65, train_loss=0.4864
# epoch 2/3, step 35/65, train_loss=0.4853
# epoch 2/3, step 36/65, train_loss=0.4845
# epoch 2/3, step 37/65, train_loss=0.4877
# epoch 2/3, step 38/65, train_loss=0.4853
# epoch 2/3, step 39/65, train_loss=0.4879
# epoch 2/3, step 40/65, train_loss=0.4836
# epoch 2/3, step 41/65, train_loss=0.4854
# epoch 2/3, step 42/65, train_loss=0.4857
# epoch 2/3, step 43/65, train_loss=0.4863
# epoch 2/3, step 44/65, train_loss=0.4861
# epoch 2/3, step 45/65, train_loss=0.4850
# epoch 2/3, step 46/65, train_loss=0.4853
# epoch 2/3, step 47/65, train_loss=0.4809
# epoch 2/3, step 48/65, train_loss=0.4815
# epoch 2/3, step 49/65, train_loss=0.4812
# epoch 2/3, step 50/65, train_loss=0.4782
# epoch 2/3, step 51/65, train_loss=0.4756
# epoch 2/3, step 52/65, train_loss=0.4808
# epoch 2/3, step 53/65, train_loss=0.4811
# epoch 2/3, step 54/65, train_loss=0.4800
# epoch 2/3, step 55/65, train_loss=0.4793
# epoch 2/3, step 56/65, train_loss=0.4774
# epoch 2/3, step 57/65, train_loss=0.4761
# epoch 2/3, step 58/65, train_loss=0.4750
# epoch 2/3, step 59/65, train_loss=0.4719
# epoch 2/3, step 60/65, train_loss=0.4748
# epoch 2/3, step 61/65, train_loss=0.4751
# epoch 2/3, step 62/65, train_loss=0.4743
# epoch 2/3, step 63/65, train_loss=0.4724
# epoch 2/3, step 64/65, train_loss=0.4722
# epoch 2/3, step 65/65, train_loss=0.4704
# epoch 2/3, step 1/17, valid_loss=0.5534
# epoch 2/3, step 2/17, valid_loss=0.5176
# epoch 2/3, step 3/17, valid_loss=0.3252
# epoch 2/3, step 4/17, valid_loss=0.6818
# epoch 2/3, step 5/17, valid_loss=0.5130
# epoch 2/3, step 6/17, valid_loss=0.4197
# epoch 2/3, step 7/17, valid_loss=0.6264
# epoch 2/3, step 8/17, valid_loss=0.3385
# epoch 2/3, step 9/17, valid_loss=0.5562
# epoch 2/3, step 10/17, valid_loss=0.4298
# epoch 2/3, step 11/17, valid_loss=0.3892
# epoch 2/3, step 12/17, valid_loss=0.5023
# epoch 2/3, step 13/17, valid_loss=0.3608
# epoch 2/3, step 14/17, valid_loss=0.5347
# epoch 2/3, step 15/17, valid_loss=0.5827
# epoch 2/3, step 16/17, valid_loss=0.4698
# epoch 2/3, step 17/17, valid_loss=0.0785
# epoch 3/3, step 1/65, train_loss=0.2770
# epoch 3/3, step 2/65, train_loss=0.2960
# epoch 3/3, step 3/65, train_loss=0.2862
# epoch 3/3, step 4/65, train_loss=0.3011
# epoch 3/3, step 5/65, train_loss=0.3102
# epoch 3/3, step 6/65, train_loss=0.3224
# epoch 3/3, step 7/65, train_loss=0.3136
# epoch 3/3, step 8/65, train_loss=0.2948
# epoch 3/3, step 9/65, train_loss=0.3164
# epoch 3/3, step 10/65, train_loss=0.3132
# epoch 3/3, step 11/65, train_loss=0.3014
# epoch 3/3, step 12/65, train_loss=0.3026
# epoch 3/3, step 13/65, train_loss=0.3049
# epoch 3/3, step 14/65, train_loss=0.2973
# epoch 3/3, step 15/65, train_loss=0.2933
# epoch 3/3, step 16/65, train_loss=0.2854
# epoch 3/3, step 17/65, train_loss=0.3039
# epoch 3/3, step 18/65, train_loss=0.2993
# epoch 3/3, step 19/65, train_loss=0.3032
# epoch 3/3, step 20/65, train_loss=0.3116
# epoch 3/3, step 21/65, train_loss=0.3264
# epoch 3/3, step 22/65, train_loss=0.3179
# epoch 3/3, step 23/65, train_loss=0.3169
# epoch 3/3, step 24/65, train_loss=0.3201
# epoch 3/3, step 25/65, train_loss=0.3112
# epoch 3/3, step 26/65, train_loss=0.3067
# epoch 3/3, step 27/65, train_loss=0.3109
# epoch 3/3, step 28/65, train_loss=0.3051
# epoch 3/3, step 29/65, train_loss=0.2987
# epoch 3/3, step 30/65, train_loss=0.3033
# epoch 3/3, step 31/65, train_loss=0.2973
# epoch 3/3, step 32/65, train_loss=0.3027
# epoch 3/3, step 33/65, train_loss=0.3050
# epoch 3/3, step 34/65, train_loss=0.3027
# epoch 3/3, step 35/65, train_loss=0.3035
# epoch 3/3, step 36/65, train_loss=0.3037
# epoch 3/3, step 37/65, train_loss=0.3013
# epoch 3/3, step 38/65, train_loss=0.3104
# epoch 3/3, step 39/65, train_loss=0.3092
# epoch 3/3, step 40/65, train_loss=0.3056
# epoch 3/3, step 41/65, train_loss=0.3064
# epoch 3/3, step 42/65, train_loss=0.3008
# epoch 3/3, step 43/65, train_loss=0.3062
# epoch 3/3, step 44/65, train_loss=0.3129
# epoch 3/3, step 45/65, train_loss=0.3090
# epoch 3/3, step 46/65, train_loss=0.3147
# epoch 3/3, step 47/65, train_loss=0.3197
# epoch 3/3, step 48/65, train_loss=0.3205
# epoch 3/3, step 49/65, train_loss=0.3202
# epoch 3/3, step 50/65, train_loss=0.3171
# epoch 3/3, step 51/65, train_loss=0.3175
# epoch 3/3, step 52/65, train_loss=0.3168
# epoch 3/3, step 53/65, train_loss=0.3125
# epoch 3/3, step 54/65, train_loss=0.3134
# epoch 3/3, step 55/65, train_loss=0.3127
# epoch 3/3, step 56/65, train_loss=0.3135
# epoch 3/3, step 57/65, train_loss=0.3096
# epoch 3/3, step 58/65, train_loss=0.3075
# epoch 3/3, step 59/65, train_loss=0.3073
# epoch 3/3, step 60/65, train_loss=0.3090
# epoch 3/3, step 61/65, train_loss=0.3163
# epoch 3/3, step 62/65, train_loss=0.3147
# epoch 3/3, step 63/65, train_loss=0.3116
# epoch 3/3, step 64/65, train_loss=0.3091
# epoch 3/3, step 65/65, train_loss=0.3134
# epoch 3/3, step 1/17, valid_loss=0.4790
# epoch 3/3, step 2/17, valid_loss=0.6123
# epoch 3/3, step 3/17, valid_loss=0.2984
# epoch 3/3, step 4/17, valid_loss=0.6783
# epoch 3/3, step 5/17, valid_loss=0.3247
# epoch 3/3, step 6/17, valid_loss=0.2647
# epoch 3/3, step 7/17, valid_loss=0.8873
# epoch 3/3, step 8/17, valid_loss=0.1598
# epoch 3/3, step 9/17, valid_loss=0.5097
# epoch 3/3, step 10/17, valid_loss=0.3171
# epoch 3/3, step 11/17, valid_loss=0.2499
# epoch 3/3, step 12/17, valid_loss=0.6063
# epoch 3/3, step 13/17, valid_loss=0.3921
# epoch 3/3, step 14/17, valid_loss=0.5706
# epoch 3/3, step 15/17, valid_loss=0.4497
# epoch 3/3, step 16/17, valid_loss=0.3376
# epoch 3/3, step 17/17, valid_loss=0.0429
# [0.6518755495904187, 0.47629645233118145, 0.3077631042031143]
# [1, 2, 3]

# %% [markdown]
# # Testing

# %%
def testing(model, test_data):
  metrics_0 = {}
  metrics_1 = {}
  test_len = test_data.shape[0]
  text_test = test_data["Text"]
  targets_test = test_data[target_list].to_numpy().reshape(-1,2)
  targets_pred = []

  model.eval()
  with torch.no_grad():
    for review in text_test:
        review = str(review)
        emb = b_tokenizer.encode_plus(review,
                                      None,
                                      add_special_tokens=True,
                                      max_length=MAX_LEN,
                                      padding="max_length",
                                      truncation=True,
                                      return_attention_mask=True,
                                      return_tensors="pt"
                                      )

        input_ids = emb["input_ids"].to(device, dtype=torch.long)
        attention_mask = emb['attention_mask'].to(device, dtype=torch.long)
        token_type_ids = emb['token_type_ids'].to(device, dtype=torch.long)

        res = model(input_ids, attention_mask, token_type_ids)
        final_res = torch.sigmoid(res).cpu().detach().numpy()

        targets_pred.append(final_res)

    targets_pred = np.array(targets_pred).reshape(-1,2)
    targets_pred = np.apply_along_axis(max_class, 1, targets_pred)

    metrics_0["accuracy_score"] = accuracy_score(targets_test[:, 0], targets_pred[:, 0])
    metrics_0["precision_score"] =  precision_score(targets_test[:, 0], targets_pred[:, 0])
    metrics_0["recall_score"] = recall_score(targets_test[:, 0], targets_pred[:, 0])
    metrics_0["f1_score"] =  f1_score(targets_test[:, 0], targets_pred[:, 0])

    metrics_1["accuracy_score"] = accuracy_score(targets_test[:, 1], targets_pred[:, 1])
    metrics_1["precision_score"] =  precision_score(targets_test[:, 1], targets_pred[:, 1])
    metrics_1["recall_score"] = recall_score(targets_test[:, 1], targets_pred[:, 1])
    metrics_1["f1_score"] =  f1_score(targets_test[:, 1], targets_pred[:, 1])

    confusion_matrix_0 = confusion_matrix(targets_test[:, 0], targets_pred[:, 0])
    confusion_matrix_1 = confusion_matrix(targets_test[:, 1], targets_pred[:, 1])

    cm_display = ConfusionMatrixDisplay(
        confusion_matrix=confusion_matrix_0,
        display_labels=[0, 1])

    print(f"metrics_0: {metrics_0}\n metrics_1: {metrics_1}")

    print(classification_report(targets_test[:, 0], targets_pred[:, 0], target_names=['Truthful', 'Fake']))
    cm_display.plot()
    plt.show()

# %%
def max_class(item):
  item = np.where(item == max(item), 1, 0)
  return item

# %%
testing(trained_model, test_data)
# Out:
# metrics_0: {'accuracy_score': 0.8310185185185185, 'precision_score': 0.8229665071770335, 'recall_score': 0.8269230769230769, 'f1_score': 0.8249400479616307}
#  metrics_1: {'accuracy_score': 0.8310185185185185, 'precision_score': 0.8385650224215246, 'recall_score': 0.8348214285714286, 'f1_score': 0.8366890380313199}
#               precision    recall  f1-score   support
#
#     Truthful       0.84      0.83      0.84       224
#         Fake       0.82      0.83      0.82       208
#
#     accuracy                           0.83       432
#    macro avg       0.83      0.83      0.83       432
# weighted avg       0.83      0.83      0.83       432

# %% [markdown]
# # Exite

# %%
exit()

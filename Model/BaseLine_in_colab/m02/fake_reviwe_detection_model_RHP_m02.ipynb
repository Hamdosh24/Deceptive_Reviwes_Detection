# %% [markdown]
# # Preprotion

# %%
import shutil
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import transformers
from sklearn.metrics import precision_score, recall_score, f1_score,\
 accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# data path
data_paths = {}
data_paths["H"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Hotel.xlsx' # hotel
data_paths["R"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Resturent.xlsx' # resturent
data_paths["P"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Prodect.xlsx' # prodect

target_list = ['Fake', 'Truthful']

# %%
b_tokenizer = transformers.AutoTokenizer.from_pretrained("/content/drive/MyDrive/Models/tokenizers-bert-base-arabertv2")

# %%
MAX_LEN = 265
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
EPOCHS = 3
LEARNING_RATE = 2.5e-05

# %% [markdown]
# # Build the Model

# %%
class AFRD(Dataset):
    def __init__(self, dataset, tokenizer, max_len):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.text = self.dataset["Text"]
        self.targets = self.dataset[target_list].values
        self.n_samples = self.dataset.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        review = str(self.text[index])
        review = " ".join(review.split())

        inputs = self.tokenizer.encode_plus(review,
                                            None,
                                            add_special_tokens=True,
                                            max_length=self.max_len,
                                            padding="max_length",
                                            truncation=True,
                                            return_attention_mask=True,
                                            return_tensors="pt"
                                            )

        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "token_type_ids": inputs["token_type_ids"].flatten(),
            "targets": torch.FloatTensor(np.array(self.targets[index])).flatten()
        }

# %%
class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = transformers.AutoModel.from_pretrained("/content/drive/MyDrive/Models/model-bert-base-arabertv2", return_dict=True)
        self.linear1 = nn.Linear(768, 256)
        self.linear2 = nn.Linear(256, 2)


    def forward(self, input_ids, attention_mask, token_type_ids):
        output = self.bert_model(input_ids, attention_mask, token_type_ids)
        output = self.linear1(output["pooler_output"])
        output = self.linear2(output)

        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /content/drive/MyDrive/Models/model-bert-base-arabertv2 and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (linear1): Linear(in_features=768, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=2, bias=True)
# )

# %% [markdown]
# # saving & loadding Function

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']

    return model, optimizer, checkpoint['epoch'], valid_loss_min.item()

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %% [markdown]
# # Loss Function & Optimizer

# %%
def loss_fn(output, target):
    return nn.BCEWithLogitsLoss()(output, target)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Training Function

# %%
def train_model(
        n_epochs,
        training_loader,
        validation_loader,
        model,
        optimizer,
        checkpoint_path,
        best_model_path
):
    train_loss_list = []
    valid_loss_list = []

    n_total_steps_train = len(training_loader)
    n_total_steps_valid = len(validation_loader)

    valid_loss_min = np.Inf

    for epoch in range(n_epochs):

        sum_train_loss = 0
        sum_valid_loss = 0
        train_loss = 0
        valid_loss = 0
        model.train()
        # train

        for index, batch in enumerate(training_loader):
            input_ids = batch["input_ids"].to(device, dtype=torch.long)
            attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
            targets = batch['targets'].to(device, dtype=torch.float)


            # forward pass
            output = model(input_ids, attention_mask, token_type_ids)

            optimizer.zero_grad()
            loss = loss_fn(output, targets)
            optimizer.zero_grad()

            # backward pass
            loss.backward()
            optimizer.step()

            train_loss = train_loss + (1/(index+1)*(loss.item()-train_loss))
            sum_train_loss += train_loss
            print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_train}, train_loss={train_loss:.4f}")
            # optimizer.zero_grad()

        # valid
        model.eval()
        with torch.no_grad():
            for index, batch in enumerate(validation_loader):
                input_ids = batch["input_ids"].to(device, dtype=torch.long)
                attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
                token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
                targets = batch['targets'].to(device, dtype=torch.float)
                output = model(input_ids, attention_mask, token_type_ids)

                loss = loss_fn(output, targets)
                valid_loss = valid_loss + (1 / (index + 1) * (loss.item() - valid_loss))
                sum_valid_loss += valid_loss
                print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_valid}, valid_loss={loss.item():.4f}")

        checkpoint = {
            "epoch": epoch + 1,
            "valid_loss_min": valid_loss,
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict()
        }

        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        train_loss_list.append(sum_train_loss/n_total_steps_train)
        valid_loss_list.append(sum_valid_loss/n_total_steps_valid)
    # Train & Valid loss Curve
    # Generate a sequence of integers to represent the epoch numbers
    epochs_r = list(range(1, n_epochs+1))
    print(train_loss_list)
    print(epochs_r)

    # Plot and label the training and validation loss values
    plt.plot(epochs_r, train_loss_list, label='Training Loss')
    plt.plot(epochs_r, valid_loss_list, label='Validation Loss')

    # Add in a title and axes labels
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Set the tick locations
    plt.xticks(range(1, n_epochs+1, 1))

    # Display the plot
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# # Test Function

# %%
def test_model(model, test_data):
  metrics_0 = {}
  metrics_1 = {}
  test_len = test_data.shape[0]
  text_test = test_data["Text"]
  targets_test = test_data[target_list].to_numpy().reshape(-1,2)
  del test_data
  targets_pred = []

  model.eval()
  with torch.no_grad():
    for review in text_test:
        review = str(review)
        emb = b_tokenizer.encode_plus(review,
                                      None,
                                      add_special_tokens=True,
                                      max_length=MAX_LEN,
                                      padding="max_length",
                                      truncation=True,
                                      return_attention_mask=True,
                                      return_tensors="pt"
                                      )

        input_ids = emb["input_ids"].to(device, dtype=torch.long)
        attention_mask = emb['attention_mask'].to(device, dtype=torch.long)
        token_type_ids = emb['token_type_ids'].to(device, dtype=torch.long)

        res = model(input_ids, attention_mask, token_type_ids)
        final_res = torch.sigmoid(res).cpu().detach().numpy()

        targets_pred.append(final_res)

  targets_pred = np.array(targets_pred).reshape(-1,2)
  targets_pred = np.apply_along_axis(max_class, 1, targets_pred)

  metrics_0["accuracy_score"] = accuracy_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["precision_score"] =  precision_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["recall_score"] = recall_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["f1_score"] =  f1_score(targets_test[:, 0], targets_pred[:, 0])

  metrics_1["accuracy_score"] = accuracy_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["precision_score"] =  precision_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["recall_score"] = recall_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["f1_score"] =  f1_score(targets_test[:, 1], targets_pred[:, 1])

  confusion_matrix_res = confusion_matrix(targets_test[:, 0], targets_pred[:, 0])

  cm_display = ConfusionMatrixDisplay(
      confusion_matrix=confusion_matrix_res,
      display_labels=[0, 1])

  print(f"metrics_0: {metrics_0}\n metrics_1: {metrics_1}")
  print(classification_report(targets_test[:, 0], targets_pred[:, 0], target_names=['Truthful', 'Fake']))
  cm_display.plot()
  plt.show()

# %%
def max_class(item):
  item = np.where(item == max(item), 1, 0)
  return item

# %% [markdown]
# # Multi data training/Testing

# %%
def pipeline(data_paths, model, optimizer, train_fn, test_fn):
  curr_stage = ''
  total_test = pd.DataFrame(columns=['Text', 'Fake', 'Truthful'])
  exe_seq = ["R", "H", "P"]
  for i in exe_seq:
    # import the data set
    data = pd.read_excel(data_paths[i])
    data.drop(labels=['Age', 'Gender','Platform/Name', 'Product', 'Rating', 'Polarity'], axis=1, inplace=True)
    target_list = ['Fake', 'Truthful']

    # encoding
    enc_y_data = pd.get_dummies(data['Class'], dtype=float)
    data[target_list] = enc_y_data[target_list]
    data.drop(labels=['Class'], axis=1, inplace=True)

    # splitting the data into train, valid, test
    train_data, test_data = train_test_split(data, test_size=0.25, random_state=32, shuffle=True)
    train_data, valid_data = train_test_split(train_data, test_size=0.2, random_state=32, shuffle=True,)

    train_data.reset_index(drop=True, inplace=True)
    valid_data.reset_index(drop=True, inplace=True)
    test_data.reset_index(drop=True, inplace=True)

    train_data = AFRD(train_data, b_tokenizer, MAX_LEN)
    valid_data = AFRD(valid_data, b_tokenizer, MAX_LEN)

    train_data_loader = DataLoader(
    train_data,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
    num_workers=0
    )

    val_data_loader = DataLoader(
    valid_data,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=0
    )
    del train_data, valid_data

    curr_stage = curr_stage + f"{i}"
    print(f'############################-{curr_stage}model-################################')
    # Training
    train_fn(EPOCHS, train_data_loader, val_data_loader, model, optimizer, f"./{curr_stage}_curr_ck.pt", f"./{curr_stage}_best.pt")
    # Testing
    test_fn(model, test_data)

    del train_data_loader, val_data_loader
    total_test = pd.concat([total_test, test_data], ignore_index=True)
    del test_data

  print('###############################-Final Test-#######################################')
  test_fn(model, total_test)

# %%
pipeline(data_paths, model, optimizer, train_model, test_model)
# Out:
# ############################-Rmodel-################################
# epoch 1/3, step 1/27, train_loss=0.6866
# epoch 1/3, step 2/27, train_loss=0.6950
# epoch 1/3, step 3/27, train_loss=0.6977
# epoch 1/3, step 4/27, train_loss=0.6994
# epoch 1/3, step 5/27, train_loss=0.6923
# epoch 1/3, step 6/27, train_loss=0.6829
# epoch 1/3, step 7/27, train_loss=0.6872
# epoch 1/3, step 8/27, train_loss=0.6872
# epoch 1/3, step 9/27, train_loss=0.6850
# epoch 1/3, step 10/27, train_loss=0.6837
# epoch 1/3, step 11/27, train_loss=0.6831
# epoch 1/3, step 12/27, train_loss=0.6785
# epoch 1/3, step 13/27, train_loss=0.6711
# epoch 1/3, step 14/27, train_loss=0.6720
# epoch 1/3, step 15/27, train_loss=0.6672
# epoch 1/3, step 16/27, train_loss=0.6671
# epoch 1/3, step 17/27, train_loss=0.6614
# epoch 1/3, step 18/27, train_loss=0.6600
# epoch 1/3, step 19/27, train_loss=0.6577
# epoch 1/3, step 20/27, train_loss=0.6528
# epoch 1/3, step 21/27, train_loss=0.6499
# epoch 1/3, step 22/27, train_loss=0.6441
# epoch 1/3, step 23/27, train_loss=0.6444
# epoch 1/3, step 24/27, train_loss=0.6421
# epoch 1/3, step 25/27, train_loss=0.6410
# epoch 1/3, step 26/27, train_loss=0.6401
# epoch 1/3, step 27/27, train_loss=0.6362
# epoch 1/3, step 1/7, valid_loss=0.5665
# epoch 1/3, step 2/7, valid_loss=0.4866
# epoch 1/3, step 3/7, valid_loss=0.5900
# epoch 1/3, step 4/7, valid_loss=0.5685
# epoch 1/3, step 5/7, valid_loss=0.6077
# epoch 1/3, step 6/7, valid_loss=0.7747
# epoch 1/3, step 7/7, valid_loss=0.5512
# epoch 2/3, step 1/27, train_loss=0.5547
# epoch 2/3, step 2/27, train_loss=0.5498
# epoch 2/3, step 3/27, train_loss=0.5427
# epoch 2/3, step 4/27, train_loss=0.5512
# epoch 2/3, step 5/27, train_loss=0.5404
# epoch 2/3, step 6/27, train_loss=0.5424
# epoch 2/3, step 7/27, train_loss=0.5214
# epoch 2/3, step 8/27, train_loss=0.5175
# epoch 2/3, step 9/27, train_loss=0.5297
# epoch 2/3, step 10/27, train_loss=0.5288
# epoch 2/3, step 11/27, train_loss=0.5289
# epoch 2/3, step 12/27, train_loss=0.5209
# epoch 2/3, step 13/27, train_loss=0.5202
# epoch 2/3, step 14/27, train_loss=0.5184
# epoch 2/3, step 15/27, train_loss=0.5094
# epoch 2/3, step 16/27, train_loss=0.5190
# epoch 2/3, step 17/27, train_loss=0.5091
# epoch 2/3, step 18/27, train_loss=0.4973
# epoch 2/3, step 19/27, train_loss=0.5007
# epoch 2/3, step 20/27, train_loss=0.4982
# epoch 2/3, step 21/27, train_loss=0.4913
# epoch 2/3, step 22/27, train_loss=0.4957
# epoch 2/3, step 23/27, train_loss=0.4940
# epoch 2/3, step 24/27, train_loss=0.4883
# epoch 2/3, step 25/27, train_loss=0.4850
# epoch 2/3, step 26/27, train_loss=0.4846
# epoch 2/3, step 27/27, train_loss=0.4765
# epoch 2/3, step 1/7, valid_loss=0.4021
# epoch 2/3, step 2/7, valid_loss=0.4144
# epoch 2/3, step 3/7, valid_loss=0.3747
# epoch 2/3, step 4/7, valid_loss=0.4051
# epoch 2/3, step 5/7, valid_loss=0.4522
# epoch 2/3, step 6/7, valid_loss=0.6817
# epoch 2/3, step 7/7, valid_loss=0.4520
# epoch 3/3, step 1/27, train_loss=0.4341
# epoch 3/3, step 2/27, train_loss=0.3587
# epoch 3/3, step 3/27, train_loss=0.3216
# epoch 3/3, step 4/27, train_loss=0.3246
# epoch 3/3, step 5/27, train_loss=0.2996
# epoch 3/3, step 6/27, train_loss=0.3040
# epoch 3/3, step 7/27, train_loss=0.3249
# epoch 3/3, step 8/27, train_loss=0.3155
# epoch 3/3, step 9/27, train_loss=0.3106
# epoch 3/3, step 10/27, train_loss=0.3217
# epoch 3/3, step 11/27, train_loss=0.3111
# epoch 3/3, step 12/27, train_loss=0.3086
# epoch 3/3, step 13/27, train_loss=0.3132
# epoch 3/3, step 14/27, train_loss=0.3057
# epoch 3/3, step 15/27, train_loss=0.3068
# epoch 3/3, step 16/27, train_loss=0.3018
# epoch 3/3, step 17/27, train_loss=0.3102
# epoch 3/3, step 18/27, train_loss=0.3159
# epoch 3/3, step 19/27, train_loss=0.3074
# epoch 3/3, step 20/27, train_loss=0.2976
# epoch 3/3, step 21/27, train_loss=0.2935
# epoch 3/3, step 22/27, train_loss=0.2853
# epoch 3/3, step 23/27, train_loss=0.2876
# epoch 3/3, step 24/27, train_loss=0.2925
# epoch 3/3, step 25/27, train_loss=0.2891
# epoch 3/3, step 26/27, train_loss=0.2942
# epoch 3/3, step 27/27, train_loss=0.2934
# epoch 3/3, step 1/7, valid_loss=0.2726
# epoch 3/3, step 2/7, valid_loss=0.3764
# epoch 3/3, step 3/7, valid_loss=0.1614
# epoch 3/3, step 4/7, valid_loss=0.3963
# epoch 3/3, step 5/7, valid_loss=0.3939
# epoch 3/3, step 6/7, valid_loss=0.4628
# epoch 3/3, step 7/7, valid_loss=0.4056
# [0.6691031693850654, 0.515408739315886, 0.31219066069744195]
# [1, 2, 3]
# metrics_0: {'accuracy_score': 0.8659217877094972, 'precision_score': 0.8272727272727273, 'recall_score': 0.9479166666666666, 'f1_score': 0.883495145631068}
#  metrics_1: {'accuracy_score': 0.8659217877094972, 'precision_score': 0.927536231884058, 'recall_score': 0.7710843373493976, 'f1_score': 0.8421052631578948}
#               precision    recall  f1-score   support
#
#     Truthful       0.93      0.77      0.84        83
#         Fake       0.83      0.95      0.88        96
#
#     accuracy                           0.87       179
#    macro avg       0.88      0.86      0.86       179
# weighted avg       0.87      0.87      0.86       179
# ############################-RHmodel-################################
# epoch 1/3, step 1/12, train_loss=0.6212
# epoch 1/3, step 2/12, train_loss=0.5362
# epoch 1/3, step 3/12, train_loss=0.4751
# epoch 1/3, step 4/12, train_loss=0.4722
# epoch 1/3, step 5/12, train_loss=0.4997
# epoch 1/3, step 6/12, train_loss=0.5882
# epoch 1/3, step 7/12, train_loss=0.6141
# epoch 1/3, step 8/12, train_loss=0.5976
# epoch 1/3, step 9/12, train_loss=0.5825
# epoch 1/3, step 10/12, train_loss=0.5733
# epoch 1/3, step 11/12, train_loss=0.5518
# epoch 1/3, step 12/12, train_loss=0.5331
# epoch 1/3, step 1/3, valid_loss=0.6506
# epoch 1/3, step 2/3, valid_loss=0.3004
# epoch 1/3, step 3/3, valid_loss=0.4303
# epoch 2/3, step 1/12, train_loss=0.3693
# epoch 2/3, step 2/12, train_loss=0.3091
# epoch 2/3, step 3/12, train_loss=0.3681
# epoch 2/3, step 4/12, train_loss=0.3640
# epoch 2/3, step 5/12, train_loss=0.3979
# epoch 2/3, step 6/12, train_loss=0.3829
# epoch 2/3, step 7/12, train_loss=0.3864
# epoch 2/3, step 8/12, train_loss=0.3737
# epoch 2/3, step 9/12, train_loss=0.3618
# epoch 2/3, step 10/12, train_loss=0.3567
# epoch 2/3, step 11/12, train_loss=0.3643
# epoch 2/3, step 12/12, train_loss=0.3458
# epoch 2/3, step 1/3, valid_loss=0.6633
# epoch 2/3, step 2/3, valid_loss=0.5589
# epoch 2/3, step 3/3, valid_loss=0.3513
# epoch 3/3, step 1/12, train_loss=0.2921
# epoch 3/3, step 2/12, train_loss=0.2139
# epoch 3/3, step 3/12, train_loss=0.1963
# epoch 3/3, step 4/12, train_loss=0.1982
# epoch 3/3, step 5/12, train_loss=0.2253
# epoch 3/3, step 6/12, train_loss=0.2032
# epoch 3/3, step 7/12, train_loss=0.1867
# epoch 3/3, step 8/12, train_loss=0.1871
# epoch 3/3, step 9/12, train_loss=0.2045
# epoch 3/3, step 10/12, train_loss=0.1942
# epoch 3/3, step 11/12, train_loss=0.2047
# epoch 3/3, step 12/12, train_loss=0.1992
# epoch 3/3, step 1/3, valid_loss=0.7910
# epoch 3/3, step 2/3, valid_loss=0.5182
# epoch 3/3, step 3/3, valid_loss=0.2512
# [0.5537644123935381, 0.36500209090024405, 0.2087832226229813]
# [1, 2, 3]
# metrics_0: {'accuracy_score': 0.8717948717948718, 'precision_score': 0.8529411764705882, 'recall_score': 0.8529411764705882, 'f1_score': 0.8529411764705882}
#  metrics_1: {'accuracy_score': 0.8717948717948718, 'precision_score': 0.8863636363636364, 'recall_score': 0.8863636363636364, 'f1_score': 0.8863636363636365}
#               precision    recall  f1-score   support
#
#     Truthful       0.89      0.89      0.89        44
#         Fake       0.85      0.85      0.85        34
#
#     accuracy                           0.87        78
#    macro avg       0.87      0.87      0.87        78
# weighted avg       0.87      0.87      0.87        78
# ############################-RHPmodel-################################
# epoch 1/3, step 1/27, train_loss=1.1402
# epoch 1/3, step 2/27, train_loss=1.1062
# epoch 1/3, step 3/27, train_loss=1.0721
# epoch 1/3, step 4/27, train_loss=0.9609
# epoch 1/3, step 5/27, train_loss=0.8705
# epoch 1/3, step 6/27, train_loss=0.8659
# epoch 1/3, step 7/27, train_loss=0.8241
# epoch 1/3, step 8/27, train_loss=0.7800
# epoch 1/3, step 9/27, train_loss=0.7982
# epoch 1/3, step 10/27, train_loss=0.7867
# epoch 1/3, step 11/27, train_loss=0.7655
# epoch 1/3, step 12/27, train_loss=0.7369
# epoch 1/3, step 13/27, train_loss=0.7193
# epoch 1/3, step 14/27, train_loss=0.7099
# epoch 1/3, step 15/27, train_loss=0.7007
# epoch 1/3, step 16/27, train_loss=0.6901
# epoch 1/3, step 17/27, train_loss=0.6784
# epoch 1/3, step 18/27, train_loss=0.6684
# epoch 1/3, step 19/27, train_loss=0.6535
# epoch 1/3, step 20/27, train_loss=0.6505
# epoch 1/3, step 21/27, train_loss=0.6460
# epoch 1/3, step 22/27, train_loss=0.6423
# epoch 1/3, step 23/27, train_loss=0.6369
# epoch 1/3, step 24/27, train_loss=0.6277
# epoch 1/3, step 25/27, train_loss=0.6200
# epoch 1/3, step 26/27, train_loss=0.6080
# epoch 1/3, step 27/27, train_loss=0.6045
# epoch 1/3, step 1/7, valid_loss=0.5360
# epoch 1/3, step 2/7, valid_loss=0.6599
# epoch 1/3, step 3/7, valid_loss=0.2554
# epoch 1/3, step 4/7, valid_loss=0.5617
# epoch 1/3, step 5/7, valid_loss=0.5573
# epoch 1/3, step 6/7, valid_loss=0.4609
# epoch 1/3, step 7/7, valid_loss=0.4332
# epoch 2/3, step 1/27, train_loss=0.2610
# epoch 2/3, step 2/27, train_loss=0.2843
# epoch 2/3, step 3/27, train_loss=0.2923
# epoch 2/3, step 4/27, train_loss=0.2811
# epoch 2/3, step 5/27, train_loss=0.3130
# epoch 2/3, step 6/27, train_loss=0.3170
# epoch 2/3, step 7/27, train_loss=0.3324
# epoch 2/3, step 8/27, train_loss=0.3254
# epoch 2/3, step 9/27, train_loss=0.3219
# epoch 2/3, step 10/27, train_loss=0.3288
# epoch 2/3, step 11/27, train_loss=0.3345
# epoch 2/3, step 12/27, train_loss=0.3335
# epoch 2/3, step 13/27, train_loss=0.3521
# epoch 2/3, step 14/27, train_loss=0.3407
# epoch 2/3, step 15/27, train_loss=0.3319
# epoch 2/3, step 16/27, train_loss=0.3205
# epoch 2/3, step 17/27, train_loss=0.3253
# epoch 2/3, step 18/27, train_loss=0.3163
# epoch 2/3, step 19/27, train_loss=0.3424
# epoch 2/3, step 20/27, train_loss=0.3437
# epoch 2/3, step 21/27, train_loss=0.3497
# epoch 2/3, step 22/27, train_loss=0.3377
# epoch 2/3, step 23/27, train_loss=0.3337
# epoch 2/3, step 24/27, train_loss=0.3337
# epoch 2/3, step 25/27, train_loss=0.3357
# epoch 2/3, step 26/27, train_loss=0.3361
# epoch 2/3, step 27/27, train_loss=0.3420
# epoch 2/3, step 1/7, valid_loss=0.4953
# epoch 2/3, step 2/7, valid_loss=0.6524
# epoch 2/3, step 3/7, valid_loss=0.1431
# epoch 2/3, step 4/7, valid_loss=0.6469
# epoch 2/3, step 5/7, valid_loss=0.5358
# epoch 2/3, step 6/7, valid_loss=0.4438
# epoch 2/3, step 7/7, valid_loss=0.2423
# epoch 3/3, step 1/27, train_loss=0.3642
# epoch 3/3, step 2/27, train_loss=0.4021
# epoch 3/3, step 3/27, train_loss=0.3943
# epoch 3/3, step 4/27, train_loss=0.3568
# epoch 3/3, step 5/27, train_loss=0.3198
# epoch 3/3, step 6/27, train_loss=0.2989
# epoch 3/3, step 7/27, train_loss=0.2857
# epoch 3/3, step 8/27, train_loss=0.2882
# epoch 3/3, step 9/27, train_loss=0.2772
# epoch 3/3, step 10/27, train_loss=0.2567
# epoch 3/3, step 11/27, train_loss=0.2431
# epoch 3/3, step 12/27, train_loss=0.2455
# epoch 3/3, step 13/27, train_loss=0.2457
# epoch 3/3, step 14/27, train_loss=0.2431
# epoch 3/3, step 15/27, train_loss=0.2509
# epoch 3/3, step 16/27, train_loss=0.2521
# epoch 3/3, step 17/27, train_loss=0.2633
# epoch 3/3, step 18/27, train_loss=0.2556
# epoch 3/3, step 19/27, train_loss=0.2477
# epoch 3/3, step 20/27, train_loss=0.2415
# epoch 3/3, step 21/27, train_loss=0.2352
# epoch 3/3, step 22/27, train_loss=0.2299
# epoch 3/3, step 23/27, train_loss=0.2248
# epoch 3/3, step 24/27, train_loss=0.2180
# epoch 3/3, step 25/27, train_loss=0.2141
# epoch 3/3, step 26/27, train_loss=0.2091
# epoch 3/3, step 27/27, train_loss=0.2048
# epoch 3/3, step 1/7, valid_loss=0.3496
# epoch 3/3, step 2/7, valid_loss=0.6922
# epoch 3/3, step 3/7, valid_loss=0.1652
# epoch 3/3, step 4/7, valid_loss=0.6548
# epoch 3/3, step 5/7, valid_loss=0.6056
# epoch 3/3, step 6/7, valid_loss=0.5601
# epoch 3/3, step 7/7, valid_loss=0.0790
# [0.7616037730952753, 0.3246899427065752, 0.26920176993009254]
# [1, 2, 3]
# metrics_0: {'accuracy_score': 0.8011363636363636, 'precision_score': 0.8433734939759037, 'recall_score': 0.7608695652173914, 'f1_score': 0.8}
#  metrics_1: {'accuracy_score': 0.8011363636363636, 'precision_score': 0.7634408602150538, 'recall_score': 0.8452380952380952, 'f1_score': 0.8022598870056498}
#               precision    recall  f1-score   support
#
#     Truthful       0.76      0.85      0.80        84
#         Fake       0.84      0.76      0.80        92
#
#     accuracy                           0.80       176
#    macro avg       0.80      0.80      0.80       176
# weighted avg       0.81      0.80      0.80       176
# ###############################-Final Test-#######################################
# metrics_0: {'accuracy_score': 0.8036951501154734, 'precision_score': 0.8477157360406091, 'recall_score': 0.7522522522522522, 'f1_score': 0.7971360381861576}
#  metrics_1: {'accuracy_score': 0.8036951501154734, 'precision_score': 0.7669491525423728, 'recall_score': 0.8578199052132701, 'f1_score': 0.8098434004474272}
#               precision    recall  f1-score   support
#
#     Truthful       0.77      0.86      0.81       211
#         Fake       0.85      0.75      0.80       222
#
#     accuracy                           0.80       433
#    macro avg       0.81      0.81      0.80       433
# weighted avg       0.81      0.80      0.80       433

# %% [markdown]
# # Exit

# %%
exit()

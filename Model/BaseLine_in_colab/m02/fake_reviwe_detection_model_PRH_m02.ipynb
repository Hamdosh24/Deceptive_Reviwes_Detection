# %% [markdown]
# # Preprotion

# %%
import shutil
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import transformers
from sklearn.metrics import precision_score, recall_score, f1_score,\
 accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# data path
data_paths = {}
data_paths["H"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Hotel.xlsx' # hotel
data_paths["R"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Resturent.xlsx' # resturent
data_paths["P"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Prodect.xlsx' # prodect

target_list = ['Fake', 'Truthful']

# %%
b_tokenizer = transformers.AutoTokenizer.from_pretrained("/content/drive/MyDrive/Models/tokenizers-bert-base-arabertv2")

# %%
MAX_LEN = 265
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
EPOCHS = 4
LEARNING_RATE = 2.5e-05

# %% [markdown]
# # Build the Model

# %%
class AFRD(Dataset):
    def __init__(self, dataset, tokenizer, max_len):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.text = self.dataset["Text"]
        self.targets = self.dataset[target_list].values
        self.n_samples = self.dataset.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        review = str(self.text[index])
        review = " ".join(review.split())

        inputs = self.tokenizer.encode_plus(review,
                                            None,
                                            add_special_tokens=True,
                                            max_length=self.max_len,
                                            padding="max_length",
                                            truncation=True,
                                            return_attention_mask=True,
                                            return_tensors="pt"
                                            )

        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "token_type_ids": inputs["token_type_ids"].flatten(),
            "targets": torch.FloatTensor(np.array(self.targets[index])).flatten()
        }

# %%
class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = transformers.AutoModel.from_pretrained("/content/drive/MyDrive/Models/model-bert-base-arabertv2", return_dict=True)
        self.linear1 = nn.Linear(768, 256)
        self.linear2 = nn.Linear(256, 2)


    def forward(self, input_ids, attention_mask, token_type_ids):
        output = self.bert_model(input_ids, attention_mask, token_type_ids)
        output = self.linear1(output["pooler_output"])
        output = self.linear2(output)

        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /content/drive/MyDrive/Models/model-bert-base-arabertv2 and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (linear1): Linear(in_features=768, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=2, bias=True)
# )

# %% [markdown]
# # saving & loadding Function

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']

    return model, optimizer, checkpoint['epoch'], valid_loss_min.item()

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %% [markdown]
# # Loss Function & Optimizer

# %%
def loss_fn(output, target):
    return nn.BCEWithLogitsLoss()(output, target)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Training Function

# %%
def train_model(
        n_epochs,
        training_loader,
        validation_loader,
        model,
        optimizer,
        checkpoint_path,
        best_model_path
):
    train_loss_list = []
    valid_loss_list = []

    n_total_steps_train = len(training_loader)
    n_total_steps_valid = len(validation_loader)

    valid_loss_min = np.Inf

    for epoch in range(n_epochs):

        sum_train_loss = 0
        sum_valid_loss = 0
        train_loss = 0
        valid_loss = 0
        model.train()
        # train

        for index, batch in enumerate(training_loader):
            input_ids = batch["input_ids"].to(device, dtype=torch.long)
            attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
            targets = batch['targets'].to(device, dtype=torch.float)


            # forward pass
            output = model(input_ids, attention_mask, token_type_ids)

            optimizer.zero_grad()
            loss = loss_fn(output, targets)
            optimizer.zero_grad()

            # backward pass
            loss.backward()
            optimizer.step()

            train_loss = train_loss + (1/(index+1)*(loss.item()-train_loss))
            sum_train_loss += train_loss
            print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_train}, train_loss={train_loss:.4f}")
            # optimizer.zero_grad()

        # valid
        model.eval()
        with torch.no_grad():
            for index, batch in enumerate(validation_loader):
                input_ids = batch["input_ids"].to(device, dtype=torch.long)
                attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
                token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
                targets = batch['targets'].to(device, dtype=torch.float)
                output = model(input_ids, attention_mask, token_type_ids)

                loss = loss_fn(output, targets)
                valid_loss = valid_loss + (1 / (index + 1) * (loss.item() - valid_loss))
                sum_valid_loss += valid_loss
                print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_valid}, valid_loss={loss.item():.4f}")

        checkpoint = {
            "epoch": epoch + 1,
            "valid_loss_min": valid_loss,
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict()
        }

        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        train_loss_list.append(sum_train_loss/n_total_steps_train)
        valid_loss_list.append(sum_valid_loss/n_total_steps_valid)
    # Train & Valid loss Curve
    # Generate a sequence of integers to represent the epoch numbers
    epochs_r = list(range(1, n_epochs+1))
    print(train_loss_list)
    print(epochs_r)

    # Plot and label the training and validation loss values
    plt.plot(epochs_r, train_loss_list, label='Training Loss')
    plt.plot(epochs_r, valid_loss_list, label='Validation Loss')

    # Add in a title and axes labels
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Set the tick locations
    plt.xticks(range(1, n_epochs+1, 1))

    # Display the plot
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# # Test Function

# %%
def test_model(model, test_data):
  metrics_0 = {}
  metrics_1 = {}
  test_len = test_data.shape[0]
  text_test = test_data["Text"]
  targets_test = test_data[target_list].to_numpy().reshape(-1,2)
  del test_data
  targets_pred = []

  model.eval()
  with torch.no_grad():
    for review in text_test:
        review = str(review)
        emb = b_tokenizer.encode_plus(review,
                                      None,
                                      add_special_tokens=True,
                                      max_length=MAX_LEN,
                                      padding="max_length",
                                      truncation=True,
                                      return_attention_mask=True,
                                      return_tensors="pt"
                                      )

        input_ids = emb["input_ids"].to(device, dtype=torch.long)
        attention_mask = emb['attention_mask'].to(device, dtype=torch.long)
        token_type_ids = emb['token_type_ids'].to(device, dtype=torch.long)

        res = model(input_ids, attention_mask, token_type_ids)
        final_res = torch.sigmoid(res).cpu().detach().numpy()

        targets_pred.append(final_res)

  targets_pred = np.array(targets_pred).reshape(-1,2)
  targets_pred = np.apply_along_axis(max_class, 1, targets_pred)

  metrics_0["accuracy_score"] = accuracy_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["precision_score"] =  precision_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["recall_score"] = recall_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["f1_score"] =  f1_score(targets_test[:, 0], targets_pred[:, 0])

  metrics_1["accuracy_score"] = accuracy_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["precision_score"] =  precision_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["recall_score"] = recall_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["f1_score"] =  f1_score(targets_test[:, 1], targets_pred[:, 1])

  confusion_matrix_res = confusion_matrix(targets_test[:, 0], targets_pred[:, 0])

  cm_display = ConfusionMatrixDisplay(
      confusion_matrix=confusion_matrix_res,
      display_labels=[0, 1])

  print(f"metrics_0: {metrics_0}\n metrics_1: {metrics_1}")
  print(classification_report(targets_test[:, 0], targets_pred[:, 0], target_names=['Truthful', 'Fake']))
  cm_display.plot()
  plt.show()

# %%
def max_class(item):
  item = np.where(item == max(item), 1, 0)
  return item

# %% [markdown]
# # Multi data training/Testing

# %%
def pipeline(data_paths, model, optimizer, train_fn, test_fn):
  curr_stage = ''
  total_test = pd.DataFrame(columns=['Text', 'Fake', 'Truthful'])
  exe_seq = ["P", "R", "H"]
  for i in exe_seq:
    # import the data set
    data = pd.read_excel(data_paths[i])
    data.drop(labels=['Age', 'Gender','Platform/Name', 'Product', 'Rating', 'Polarity'], axis=1, inplace=True)
    target_list = ['Fake', 'Truthful']

    # encoding
    enc_y_data = pd.get_dummies(data['Class'], dtype=float)
    data[target_list] = enc_y_data[target_list]
    data.drop(labels=['Class'], axis=1, inplace=True)

    # splitting the data into train, valid, test
    train_data, test_data = train_test_split(data, test_size=0.25, random_state=32, shuffle=True)
    train_data, valid_data = train_test_split(train_data, test_size=0.2, random_state=32, shuffle=True,)

    train_data.reset_index(drop=True, inplace=True)
    valid_data.reset_index(drop=True, inplace=True)
    test_data.reset_index(drop=True, inplace=True)

    train_data = AFRD(train_data, b_tokenizer, MAX_LEN)
    valid_data = AFRD(valid_data, b_tokenizer, MAX_LEN)

    train_data_loader = DataLoader(
    train_data,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
    num_workers=0
    )

    val_data_loader = DataLoader(
    valid_data,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=0
    )
    del train_data, valid_data

    curr_stage = curr_stage + f"{i}"
    print(f'############################-{curr_stage}model-################################')
    # Training
    train_fn(EPOCHS, train_data_loader, val_data_loader, model, optimizer, f"./{curr_stage}_curr_ck.pt", f"./{curr_stage}_best.pt")
    # Testing
    test_fn(model, test_data)

    del train_data_loader, val_data_loader
    total_test = pd.concat([total_test, test_data], ignore_index=True)
    del test_data
  print('###############################-Final Test-#######################################')
  test_fn(model, total_test)

# %%
pipeline(data_paths, model, optimizer, train_model, test_model)
# Out:
# ############################-Pmodel-################################
# epoch 1/4, step 1/27, train_loss=0.7085
# epoch 1/4, step 2/27, train_loss=0.7062
# epoch 1/4, step 3/27, train_loss=0.7053
# epoch 1/4, step 4/27, train_loss=0.7033
# epoch 1/4, step 5/27, train_loss=0.7017
# epoch 1/4, step 6/27, train_loss=0.6979
# epoch 1/4, step 7/27, train_loss=0.6941
# epoch 1/4, step 8/27, train_loss=0.6901
# epoch 1/4, step 9/27, train_loss=0.6868
# epoch 1/4, step 10/27, train_loss=0.6851
# epoch 1/4, step 11/27, train_loss=0.6855
# epoch 1/4, step 12/27, train_loss=0.6838
# epoch 1/4, step 13/27, train_loss=0.6787
# epoch 1/4, step 14/27, train_loss=0.6772
# epoch 1/4, step 15/27, train_loss=0.6838
# epoch 1/4, step 16/27, train_loss=0.6883
# epoch 1/4, step 17/27, train_loss=0.6913
# epoch 1/4, step 18/27, train_loss=0.6914
# epoch 1/4, step 19/27, train_loss=0.6885
# epoch 1/4, step 20/27, train_loss=0.6883
# epoch 1/4, step 21/27, train_loss=0.6875
# epoch 1/4, step 22/27, train_loss=0.6853
# epoch 1/4, step 23/27, train_loss=0.6872
# epoch 1/4, step 24/27, train_loss=0.6881
# epoch 1/4, step 25/27, train_loss=0.6861
# epoch 1/4, step 26/27, train_loss=0.6837
# epoch 1/4, step 27/27, train_loss=0.6828
# epoch 1/4, step 1/7, valid_loss=0.6629
# epoch 1/4, step 2/7, valid_loss=0.6559
# epoch 1/4, step 3/7, valid_loss=0.6002
# epoch 1/4, step 4/7, valid_loss=0.6355
# epoch 1/4, step 5/7, valid_loss=0.7066
# epoch 1/4, step 6/7, valid_loss=0.6338
# epoch 1/4, step 7/7, valid_loss=0.6498
# epoch 2/4, step 1/27, train_loss=0.6515
# epoch 2/4, step 2/27, train_loss=0.6575
# epoch 2/4, step 3/27, train_loss=0.6414
# epoch 2/4, step 4/27, train_loss=0.6330
# epoch 2/4, step 5/27, train_loss=0.6273
# epoch 2/4, step 6/27, train_loss=0.6129
# epoch 2/4, step 7/27, train_loss=0.6100
# epoch 2/4, step 8/27, train_loss=0.6085
# epoch 2/4, step 9/27, train_loss=0.6100
# epoch 2/4, step 10/27, train_loss=0.6113
# epoch 2/4, step 11/27, train_loss=0.6122
# epoch 2/4, step 12/27, train_loss=0.6081
# epoch 2/4, step 13/27, train_loss=0.6011
# epoch 2/4, step 14/27, train_loss=0.5935
# epoch 2/4, step 15/27, train_loss=0.5934
# epoch 2/4, step 16/27, train_loss=0.5924
# epoch 2/4, step 17/27, train_loss=0.5854
# epoch 2/4, step 18/27, train_loss=0.5803
# epoch 2/4, step 19/27, train_loss=0.5840
# epoch 2/4, step 20/27, train_loss=0.5803
# epoch 2/4, step 21/27, train_loss=0.5770
# epoch 2/4, step 22/27, train_loss=0.5719
# epoch 2/4, step 23/27, train_loss=0.5690
# epoch 2/4, step 24/27, train_loss=0.5622
# epoch 2/4, step 25/27, train_loss=0.5560
# epoch 2/4, step 26/27, train_loss=0.5561
# epoch 2/4, step 27/27, train_loss=0.5625
# epoch 2/4, step 1/7, valid_loss=0.5554
# epoch 2/4, step 2/7, valid_loss=0.5468
# epoch 2/4, step 3/7, valid_loss=0.5211
# epoch 2/4, step 4/7, valid_loss=0.4352
# epoch 2/4, step 5/7, valid_loss=0.7236
# epoch 2/4, step 6/7, valid_loss=0.5214
# epoch 2/4, step 7/7, valid_loss=0.3967
# epoch 3/4, step 1/27, train_loss=0.3686
# epoch 3/4, step 2/27, train_loss=0.3443
# epoch 3/4, step 3/27, train_loss=0.3835
# epoch 3/4, step 4/27, train_loss=0.3845
# epoch 3/4, step 5/27, train_loss=0.3769
# epoch 3/4, step 6/27, train_loss=0.3651
# epoch 3/4, step 7/27, train_loss=0.3629
# epoch 3/4, step 8/27, train_loss=0.3416
# epoch 3/4, step 9/27, train_loss=0.3485
# epoch 3/4, step 10/27, train_loss=0.3438
# epoch 3/4, step 11/27, train_loss=0.3336
# epoch 3/4, step 12/27, train_loss=0.3378
# epoch 3/4, step 13/27, train_loss=0.3359
# epoch 3/4, step 14/27, train_loss=0.3458
# epoch 3/4, step 15/27, train_loss=0.3535
# epoch 3/4, step 16/27, train_loss=0.3472
# epoch 3/4, step 17/27, train_loss=0.3475
# epoch 3/4, step 18/27, train_loss=0.3557
# epoch 3/4, step 19/27, train_loss=0.3488
# epoch 3/4, step 20/27, train_loss=0.3497
# epoch 3/4, step 21/27, train_loss=0.3576
# epoch 3/4, step 22/27, train_loss=0.3532
# epoch 3/4, step 23/27, train_loss=0.3647
# epoch 3/4, step 24/27, train_loss=0.3653
# epoch 3/4, step 25/27, train_loss=0.3713
# epoch 3/4, step 26/27, train_loss=0.3633
# epoch 3/4, step 27/27, train_loss=0.3531
# epoch 3/4, step 1/7, valid_loss=0.5101
# epoch 3/4, step 2/7, valid_loss=0.7343
# epoch 3/4, step 3/7, valid_loss=0.2288
# epoch 3/4, step 4/7, valid_loss=0.5736
# epoch 3/4, step 5/7, valid_loss=0.4760
# epoch 3/4, step 6/7, valid_loss=0.5045
# epoch 3/4, step 7/7, valid_loss=0.4660
# epoch 4/4, step 1/27, train_loss=0.2623
# epoch 4/4, step 2/27, train_loss=0.2571
# epoch 4/4, step 3/27, train_loss=0.2931
# epoch 4/4, step 4/27, train_loss=0.3176
# epoch 4/4, step 5/27, train_loss=0.2767
# epoch 4/4, step 6/27, train_loss=0.2837
# epoch 4/4, step 7/27, train_loss=0.2785
# epoch 4/4, step 8/27, train_loss=0.2636
# epoch 4/4, step 9/27, train_loss=0.2593
# epoch 4/4, step 10/27, train_loss=0.2517
# epoch 4/4, step 11/27, train_loss=0.2421
# epoch 4/4, step 12/27, train_loss=0.2414
# epoch 4/4, step 13/27, train_loss=0.2432
# epoch 4/4, step 14/27, train_loss=0.2420
# epoch 4/4, step 15/27, train_loss=0.2408
# epoch 4/4, step 16/27, train_loss=0.2422
# epoch 4/4, step 17/27, train_loss=0.2407
# epoch 4/4, step 18/27, train_loss=0.2470
# epoch 4/4, step 19/27, train_loss=0.2486
# epoch 4/4, step 20/27, train_loss=0.2521
# epoch 4/4, step 21/27, train_loss=0.2437
# epoch 4/4, step 22/27, train_loss=0.2452
# epoch 4/4, step 23/27, train_loss=0.2419
# epoch 4/4, step 24/27, train_loss=0.2391
# epoch 4/4, step 25/27, train_loss=0.2330
# epoch 4/4, step 26/27, train_loss=0.2261
# epoch 4/4, step 27/27, train_loss=0.2216
# epoch 4/4, step 1/7, valid_loss=0.4821
# epoch 4/4, step 2/7, valid_loss=0.8965
# epoch 4/4, step 3/7, valid_loss=0.1205
# epoch 4/4, step 4/7, valid_loss=0.7320
# epoch 4/4, step 5/7, valid_loss=0.6720
# epoch 4/4, step 6/7, valid_loss=0.4194
# epoch 4/4, step 7/7, valid_loss=0.3343
# [0.6902444717031114, 0.5980988607161373, 0.3556990195207814, 0.25312997735814863]
# [1, 2, 3, 4]
# metrics_0: {'accuracy_score': 0.8011363636363636, 'precision_score': 0.8202247191011236, 'recall_score': 0.7934782608695652, 'f1_score': 0.8066298342541436}
#  metrics_1: {'accuracy_score': 0.8011363636363636, 'precision_score': 0.7816091954022989, 'recall_score': 0.8095238095238095, 'f1_score': 0.7953216374269005}
#               precision    recall  f1-score   support
#
#     Truthful       0.78      0.81      0.80        84
#         Fake       0.82      0.79      0.81        92
#
#     accuracy                           0.80       176
#    macro avg       0.80      0.80      0.80       176
# weighted avg       0.80      0.80      0.80       176
# ############################-PRmodel-################################
# epoch 1/4, step 1/27, train_loss=0.7068
# epoch 1/4, step 2/27, train_loss=0.5747
# epoch 1/4, step 3/27, train_loss=0.6413
# epoch 1/4, step 4/27, train_loss=0.8337
# epoch 1/4, step 5/27, train_loss=0.7692
# epoch 1/4, step 6/27, train_loss=0.7882
# epoch 1/4, step 7/27, train_loss=0.7704
# epoch 1/4, step 8/27, train_loss=0.7491
# epoch 1/4, step 9/27, train_loss=0.7254
# epoch 1/4, step 10/27, train_loss=0.7089
# epoch 1/4, step 11/27, train_loss=0.6826
# epoch 1/4, step 12/27, train_loss=0.6638
# epoch 1/4, step 13/27, train_loss=0.6560
# epoch 1/4, step 14/27, train_loss=0.6386
# epoch 1/4, step 15/27, train_loss=0.6391
# epoch 1/4, step 16/27, train_loss=0.6292
# epoch 1/4, step 17/27, train_loss=0.6214
# epoch 1/4, step 18/27, train_loss=0.6244
# epoch 1/4, step 19/27, train_loss=0.6264
# epoch 1/4, step 20/27, train_loss=0.6232
# epoch 1/4, step 21/27, train_loss=0.6171
# epoch 1/4, step 22/27, train_loss=0.6090
# epoch 1/4, step 23/27, train_loss=0.5989
# epoch 1/4, step 24/27, train_loss=0.5919
# epoch 1/4, step 25/27, train_loss=0.5889
# epoch 1/4, step 26/27, train_loss=0.5798
# epoch 1/4, step 27/27, train_loss=0.5784
# epoch 1/4, step 1/7, valid_loss=0.4176
# epoch 1/4, step 2/7, valid_loss=0.4156
# epoch 1/4, step 3/7, valid_loss=0.5803
# epoch 1/4, step 4/7, valid_loss=0.5333
# epoch 1/4, step 5/7, valid_loss=0.5366
# epoch 1/4, step 6/7, valid_loss=0.8846
# epoch 1/4, step 7/7, valid_loss=0.3731
# epoch 2/4, step 1/27, train_loss=0.3979
# epoch 2/4, step 2/27, train_loss=0.3188
# epoch 2/4, step 3/27, train_loss=0.2755
# epoch 2/4, step 4/27, train_loss=0.2984
# epoch 2/4, step 5/27, train_loss=0.2900
# epoch 2/4, step 6/27, train_loss=0.3048
# epoch 2/4, step 7/27, train_loss=0.3029
# epoch 2/4, step 8/27, train_loss=0.2887
# epoch 2/4, step 9/27, train_loss=0.2865
# epoch 2/4, step 10/27, train_loss=0.2992
# epoch 2/4, step 11/27, train_loss=0.3065
# epoch 2/4, step 12/27, train_loss=0.3095
# epoch 2/4, step 13/27, train_loss=0.2987
# epoch 2/4, step 14/27, train_loss=0.2986
# epoch 2/4, step 15/27, train_loss=0.2938
# epoch 2/4, step 16/27, train_loss=0.2840
# epoch 2/4, step 17/27, train_loss=0.3004
# epoch 2/4, step 18/27, train_loss=0.2927
# epoch 2/4, step 19/27, train_loss=0.3010
# epoch 2/4, step 20/27, train_loss=0.2947
# epoch 2/4, step 21/27, train_loss=0.3011
# epoch 2/4, step 22/27, train_loss=0.3151
# epoch 2/4, step 23/27, train_loss=0.3101
# epoch 2/4, step 24/27, train_loss=0.3055
# epoch 2/4, step 25/27, train_loss=0.3067
# epoch 2/4, step 26/27, train_loss=0.3023
# epoch 2/4, step 27/27, train_loss=0.2975
# epoch 2/4, step 1/7, valid_loss=0.2312
# epoch 2/4, step 2/7, valid_loss=0.3558
# epoch 2/4, step 3/7, valid_loss=0.1045
# epoch 2/4, step 4/7, valid_loss=0.0966
# epoch 2/4, step 5/7, valid_loss=0.4009
# epoch 2/4, step 6/7, valid_loss=0.5077
# epoch 2/4, step 7/7, valid_loss=0.1038
# epoch 3/4, step 1/27, train_loss=0.3492
# epoch 3/4, step 2/27, train_loss=0.2861
# epoch 3/4, step 3/27, train_loss=0.2374
# epoch 3/4, step 4/27, train_loss=0.1980
# epoch 3/4, step 5/27, train_loss=0.1916
# epoch 3/4, step 6/27, train_loss=0.1915
# epoch 3/4, step 7/27, train_loss=0.1768
# epoch 3/4, step 8/27, train_loss=0.1740
# epoch 3/4, step 9/27, train_loss=0.1723
# epoch 3/4, step 10/27, train_loss=0.1649
# epoch 3/4, step 11/27, train_loss=0.1556
# epoch 3/4, step 12/27, train_loss=0.1725
# epoch 3/4, step 13/27, train_loss=0.1705
# epoch 3/4, step 14/27, train_loss=0.1651
# epoch 3/4, step 15/27, train_loss=0.1650
# epoch 3/4, step 16/27, train_loss=0.1757
# epoch 3/4, step 17/27, train_loss=0.2049
# epoch 3/4, step 18/27, train_loss=0.2037
# epoch 3/4, step 19/27, train_loss=0.1951
# epoch 3/4, step 20/27, train_loss=0.1869
# epoch 3/4, step 21/27, train_loss=0.1809
# epoch 3/4, step 22/27, train_loss=0.1756
# epoch 3/4, step 23/27, train_loss=0.1768
# epoch 3/4, step 24/27, train_loss=0.1760
# epoch 3/4, step 25/27, train_loss=0.1793
# epoch 3/4, step 26/27, train_loss=0.1741
# epoch 3/4, step 27/27, train_loss=0.1748
# epoch 3/4, step 1/7, valid_loss=0.2883
# epoch 3/4, step 2/7, valid_loss=0.2184
# epoch 3/4, step 3/7, valid_loss=0.2413
# epoch 3/4, step 4/7, valid_loss=0.1860
# epoch 3/4, step 5/7, valid_loss=0.2616
# epoch 3/4, step 6/7, valid_loss=1.3586
# epoch 3/4, step 7/7, valid_loss=0.3089
# epoch 4/4, step 1/27, train_loss=0.2440
# epoch 4/4, step 2/27, train_loss=0.1351
# epoch 4/4, step 3/27, train_loss=0.1126
# epoch 4/4, step 4/27, train_loss=0.0913
# epoch 4/4, step 5/27, train_loss=0.0880
# epoch 4/4, step 6/27, train_loss=0.0899
# epoch 4/4, step 7/27, train_loss=0.1002
# epoch 4/4, step 8/27, train_loss=0.1061
# epoch 4/4, step 9/27, train_loss=0.1010
# epoch 4/4, step 10/27, train_loss=0.0935
# epoch 4/4, step 11/27, train_loss=0.0866
# epoch 4/4, step 12/27, train_loss=0.0969
# epoch 4/4, step 13/27, train_loss=0.1026
# epoch 4/4, step 14/27, train_loss=0.0968
# epoch 4/4, step 15/27, train_loss=0.0924
# epoch 4/4, step 16/27, train_loss=0.0890
# epoch 4/4, step 17/27, train_loss=0.0849
# epoch 4/4, step 18/27, train_loss=0.0937
# epoch 4/4, step 19/27, train_loss=0.1001
# epoch 4/4, step 20/27, train_loss=0.0968
# epoch 4/4, step 21/27, train_loss=0.0961
# epoch 4/4, step 22/27, train_loss=0.0934
# epoch 4/4, step 23/27, train_loss=0.0902
# epoch 4/4, step 24/27, train_loss=0.0885
# epoch 4/4, step 25/27, train_loss=0.0878
# epoch 4/4, step 26/27, train_loss=0.0857
# epoch 4/4, step 27/27, train_loss=0.0838
# epoch 4/4, step 1/7, valid_loss=0.3254
# epoch 4/4, step 2/7, valid_loss=0.2973
# epoch 4/4, step 3/7, valid_loss=0.1934
# epoch 4/4, step 4/7, valid_loss=0.0539
# epoch 4/4, step 5/7, valid_loss=0.2616
# epoch 4/4, step 6/7, valid_loss=1.2169
# epoch 4/4, step 7/7, valid_loss=0.0372
# [0.6606074999409941, 0.302992974913281, 0.19164259509367665, 0.10100220482827904]
# [1, 2, 3, 4]
# metrics_0: {'accuracy_score': 0.8435754189944135, 'precision_score': 0.9146341463414634, 'recall_score': 0.78125, 'f1_score': 0.8426966292134832}
#  metrics_1: {'accuracy_score': 0.8435754189944135, 'precision_score': 0.7835051546391752, 'recall_score': 0.9156626506024096, 'f1_score': 0.8444444444444443}
#               precision    recall  f1-score   support
#
#     Truthful       0.78      0.92      0.84        83
#         Fake       0.91      0.78      0.84        96
#
#     accuracy                           0.84       179
#    macro avg       0.85      0.85      0.84       179
# weighted avg       0.85      0.84      0.84       179
# ############################-PRHmodel-################################
# epoch 1/4, step 1/12, train_loss=0.4424
# epoch 1/4, step 2/12, train_loss=0.4613
# epoch 1/4, step 3/12, train_loss=0.3525
# epoch 1/4, step 6/12, train_loss=0.5298
# epoch 1/4, step 7/12, train_loss=0.4683
# epoch 1/4, step 8/12, train_loss=0.4497
# epoch 1/4, step 9/12, train_loss=0.4092
# epoch 1/4, step 10/12, train_loss=0.3832
# epoch 1/4, step 11/12, train_loss=0.4077
# epoch 1/4, step 12/12, train_loss=0.4084
# epoch 1/4, step 1/3, valid_loss=0.4788
# epoch 1/4, step 2/3, valid_loss=0.4405
# epoch 1/4, step 3/3, valid_loss=0.1138
# epoch 2/4, step 1/12, train_loss=0.1466
# epoch 2/4, step 2/12, train_loss=0.2771
# epoch 2/4, step 3/12, train_loss=0.2237
# epoch 2/4, step 4/12, train_loss=0.2086
# epoch 2/4, step 5/12, train_loss=0.1878
# epoch 2/4, step 6/12, train_loss=0.1989
# epoch 2/4, step 7/12, train_loss=0.1975
# epoch 2/4, step 8/12, train_loss=0.1943
# epoch 2/4, step 9/12, train_loss=0.1846
# epoch 2/4, step 10/12, train_loss=0.2012
# epoch 2/4, step 11/12, train_loss=0.2026
# epoch 2/4, step 12/12, train_loss=0.1897
# epoch 2/4, step 1/3, valid_loss=0.4595
# epoch 2/4, step 2/3, valid_loss=0.3357
# epoch 2/4, step 3/3, valid_loss=0.1133
# epoch 3/4, step 1/12, train_loss=0.0600
# epoch 3/4, step 2/12, train_loss=0.0626
# epoch 3/4, step 3/12, train_loss=0.0712
# epoch 3/4, step 4/12, train_loss=0.0682
# epoch 3/4, step 5/12, train_loss=0.0685
# epoch 3/4, step 6/12, train_loss=0.0696
# epoch 3/4, step 7/12, train_loss=0.0642
# epoch 3/4, step 8/12, train_loss=0.0674
# epoch 3/4, step 9/12, train_loss=0.0624
# epoch 3/4, step 10/12, train_loss=0.0633
# epoch 3/4, step 11/12, train_loss=0.0620
# epoch 3/4, step 12/12, train_loss=0.0593
# epoch 3/4, step 1/3, valid_loss=0.5552
# epoch 3/4, step 2/3, valid_loss=0.4782
# epoch 3/4, step 3/3, valid_loss=0.0235
# epoch 4/4, step 1/12, train_loss=0.0791
# epoch 4/4, step 2/12, train_loss=0.0540
# epoch 4/4, step 3/12, train_loss=0.0404
# epoch 4/4, step 4/12, train_loss=0.0341
# epoch 4/4, step 5/12, train_loss=0.0520
# epoch 4/4, step 6/12, train_loss=0.0461
# epoch 4/4, step 7/12, train_loss=0.0427
# epoch 4/4, step 8/12, train_loss=0.0398
# epoch 4/4, step 9/12, train_loss=0.0367
# epoch 4/4, step 10/12, train_loss=0.0342
# epoch 4/4, step 11/12, train_loss=0.0321
# epoch 4/4, step 12/12, train_loss=0.0312
# epoch 4/4, step 1/3, valid_loss=0.5712
# epoch 4/4, step 2/3, valid_loss=0.4925
# epoch 4/4, step 3/3, valid_loss=0.0116
# [0.4375818269016394, 0.2010446956233821, 0.06490168008331107, 0.04354919593238577]
# [1, 2, 3, 4]
# metrics_0: {'accuracy_score': 0.8974358974358975, 'precision_score': 0.8611111111111112, 'recall_score': 0.9117647058823529, 'f1_score': 0.8857142857142858}
#  metrics_1: {'accuracy_score': 0.8974358974358975, 'precision_score': 0.9285714285714286, 'recall_score': 0.8863636363636364, 'f1_score': 0.9069767441860465}
#               precision    recall  f1-score   support
#
#     Truthful       0.93      0.89      0.91        44
#         Fake       0.86      0.91      0.89        34
#
#     accuracy                           0.90        78
#    macro avg       0.89      0.90      0.90        78
# weighted avg       0.90      0.90      0.90        78
# ###############################-Final Test-#######################################
# metrics_0: {'accuracy_score': 0.812933025404157, 'precision_score': 0.8691099476439791, 'recall_score': 0.7477477477477478, 'f1_score': 0.8038740920096853}
#  metrics_1: {'accuracy_score': 0.812933025404157, 'precision_score': 0.768595041322314, 'recall_score': 0.8815165876777251, 'f1_score': 0.8211920529801325}
#               precision    recall  f1-score   support
#
#     Truthful       0.77      0.88      0.82       211
#         Fake       0.87      0.75      0.80       222
#
#     accuracy                           0.81       433
#    macro avg       0.82      0.81      0.81       433
# weighted avg       0.82      0.81      0.81       433

# %% [markdown]
# # Exit

# %%
exit()

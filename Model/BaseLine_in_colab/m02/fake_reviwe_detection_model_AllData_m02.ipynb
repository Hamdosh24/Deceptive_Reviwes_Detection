# %% [markdown]
# # Preprotion

# %%
import shutil
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import transformers
from sklearn.metrics import precision_score, recall_score, f1_score,\
 accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Bulding the model

# %%
data_paths = {}
data_paths["H"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Hotel.xlsx' # hotel
data_paths["R"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Resturent.xlsx' # resturent
data_paths["P"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Prodect.xlsx' # prodect

h_data = pd.read_excel(data_paths['H'])
r_data = pd.read_excel(data_paths['R'])
p_data = pd.read_excel(data_paths['P'])

data = pd.concat([h_data, r_data], ignore_index=True)
data = pd.concat([data, p_data], ignore_index=True)

del data_paths, h_data, r_data, p_data

data.drop(labels=['Age', 'Gender','Platform/Name', 'Product', 'Rating', 'Polarity'], axis=1, inplace=True)
target_list = ['Fake', 'Truthful']

enc_y_data = pd.get_dummies(data['Class'], dtype=float)
data[target_list] = enc_y_data[target_list]
data.drop(labels=['Class'], axis=1, inplace=True)

# %%
train_data, test_data = train_test_split(data, test_size=0.25, random_state=32, shuffle=True)

# %%
MAX_LEN = 265
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
EPOCHS = 3
LEARNING_RATE = 2.5e-05

# %%
b_tokenizer = transformers.AutoTokenizer.from_pretrained("/content/drive/MyDrive/Models/tokenizers-bert-base-arabertv2")

# %%
class AFRD(Dataset):
    def __init__(self, dataset, tokenizer, max_len):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.text = self.dataset["Text"]
        self.targets = self.dataset[target_list].values
        self.n_samples = self.dataset.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        review = str(self.text[index])
        review = " ".join(review.split())

        inputs = self.tokenizer.encode_plus(review,
                                            None,
                                            add_special_tokens=True,
                                            max_length=self.max_len,
                                            padding="max_length",
                                            truncation=True,
                                            return_attention_mask=True,
                                            return_tensors="pt"
                                            )

        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "token_type_ids": inputs["token_type_ids"].flatten(),
            "targets": torch.FloatTensor(np.array(self.targets[index])).flatten()
        }

# %%
train_data, valid_data = train_test_split(train_data, test_size=0.2, random_state=32, shuffle=True,)

train_data.reset_index(drop=True, inplace=True)
valid_data.reset_index(drop=True, inplace=True)

train_set = AFRD(train_data, b_tokenizer, MAX_LEN)
valid_set = AFRD(valid_data, b_tokenizer, MAX_LEN)

# %%
train_data_loader = DataLoader(
    train_set,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
    num_workers=0
)

val_data_loader = DataLoader(
    valid_set,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=0
)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']

    return model, optimizer, checkpoint['epoch'], valid_loss_min.item()

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %%
class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = transformers.AutoModel.from_pretrained("/content/drive/MyDrive/Models/model-bert-base-arabertv2", return_dict=True)
        self.linear1 = nn.Linear(768, 256)
        self.linear2 = nn.Linear(256, 2)


    def forward(self, input_ids, attention_mask, token_type_ids):
        output = self.bert_model(input_ids, attention_mask, token_type_ids)
        output = self.linear1(output["pooler_output"])
        output = self.linear2(output)

        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /content/drive/MyDrive/Models/model-bert-base-arabertv2 and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (linear1): Linear(in_features=768, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
def loss_fn(output, target):
    return nn.BCEWithLogitsLoss()(output, target)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Trainning

# %%
def train_model(
        n_epochs,
        training_loader,
        validation_loader,
        model,
        optimizer,
        checkpoint_path,
        best_model_path
):
    train_loss_list = []
    valid_loss_list = []

    n_total_steps_train = len(training_loader)
    n_total_steps_valid = len(validation_loader)

    valid_loss_min = np.Inf

    for epoch in range(n_epochs):

        sum_train_loss = 0
        sum_valid_loss = 0
        train_loss = 0
        valid_loss = 0
        model.train()
        # train

        for index, batch in enumerate(training_loader):
            input_ids = batch["input_ids"].to(device, dtype=torch.long)
            attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
            targets = batch['targets'].to(device, dtype=torch.float)


            # forward pass
            output = model(input_ids, attention_mask, token_type_ids)

            optimizer.zero_grad()
            loss = loss_fn(output, targets)
            optimizer.zero_grad()

            # backward pass
            loss.backward()
            optimizer.step()

            train_loss = train_loss + (1/(index+1)*(loss.item()-train_loss))
            sum_train_loss += train_loss
            print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_train}, train_loss={train_loss:.4f}")
            # optimizer.zero_grad()

        # valid
        model.eval()
        with torch.no_grad():
            for index, batch in enumerate(validation_loader):
                input_ids = batch["input_ids"].to(device, dtype=torch.long)
                attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
                token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
                targets = batch['targets'].to(device, dtype=torch.float)
                output = model(input_ids, attention_mask, token_type_ids)

                loss = loss_fn(output, targets)
                valid_loss = valid_loss + (1 / (index + 1) * (loss.item() - valid_loss))
                sum_valid_loss += valid_loss
                print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_valid}, valid_loss={loss.item():.4f}")

        checkpoint = {
            "epoch": epoch + 1,
            "valid_loss_min": valid_loss,
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict()
        }

        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        train_loss_list.append(sum_train_loss/n_total_steps_train)
        valid_loss_list.append(sum_valid_loss/n_total_steps_valid)
    # Train & Valid loss Curve
    # Generate a sequence of integers to represent the epoch numbers
    epochs_r = list(range(1, n_epochs+1))
    print(train_loss_list)
    print(epochs_r)

    # Plot and label the training and validation loss values
    plt.plot(epochs_r, train_loss_list, label='Training Loss')
    plt.plot(epochs_r, valid_loss_list, label='Validation Loss')

    # Add in a title and axes labels
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Set the tick locations
    plt.xticks(range(1, n_epochs+1, 1))

    # Display the plot
    plt.legend(loc='best')
    plt.show()
    return model

# %%
trained_model = train_model(EPOCHS, train_data_loader, val_data_loader, model, optimizer, "./curr_ckpt", "./best.pt")
# Out:
# epoch 1/3, step 1/65, train_loss=0.7001
# epoch 1/3, step 2/65, train_loss=0.6941
# epoch 1/3, step 3/65, train_loss=0.6978
# epoch 1/3, step 4/65, train_loss=0.6924
# epoch 1/3, step 5/65, train_loss=0.6878
# epoch 1/3, step 6/65, train_loss=0.6850
# epoch 1/3, step 7/65, train_loss=0.6829
# epoch 1/3, step 8/65, train_loss=0.6811
# epoch 1/3, step 9/65, train_loss=0.6805
# epoch 1/3, step 10/65, train_loss=0.6813
# epoch 1/3, step 11/65, train_loss=0.6802
# epoch 1/3, step 12/65, train_loss=0.6803
# epoch 1/3, step 13/65, train_loss=0.6807
# epoch 1/3, step 14/65, train_loss=0.6784
# epoch 1/3, step 15/65, train_loss=0.6755
# epoch 1/3, step 16/65, train_loss=0.6744
# epoch 1/3, step 17/65, train_loss=0.6712
# epoch 1/3, step 18/65, train_loss=0.6739
# epoch 1/3, step 19/65, train_loss=0.6757
# epoch 1/3, step 20/65, train_loss=0.6744
# epoch 1/3, step 21/65, train_loss=0.6691
# epoch 1/3, step 22/65, train_loss=0.6699
# epoch 1/3, step 23/65, train_loss=0.6670
# epoch 1/3, step 24/65, train_loss=0.6674
# epoch 1/3, step 25/65, train_loss=0.6681
# epoch 1/3, step 26/65, train_loss=0.6702
# epoch 1/3, step 27/65, train_loss=0.6737
# epoch 1/3, step 28/65, train_loss=0.6729
# epoch 1/3, step 29/65, train_loss=0.6718
# epoch 1/3, step 30/65, train_loss=0.6706
# epoch 1/3, step 31/65, train_loss=0.6687
# epoch 1/3, step 32/65, train_loss=0.6685
# epoch 1/3, step 33/65, train_loss=0.6679
# epoch 1/3, step 34/65, train_loss=0.6679
# epoch 1/3, step 35/65, train_loss=0.6703
# epoch 1/3, step 36/65, train_loss=0.6685
# epoch 1/3, step 37/65, train_loss=0.6679
# epoch 1/3, step 38/65, train_loss=0.6661
# epoch 1/3, step 39/65, train_loss=0.6652
# epoch 1/3, step 40/65, train_loss=0.6631
# epoch 1/3, step 41/65, train_loss=0.6613
# epoch 1/3, step 42/65, train_loss=0.6614
# epoch 1/3, step 43/65, train_loss=0.6608
# epoch 1/3, step 44/65, train_loss=0.6604
# epoch 1/3, step 45/65, train_loss=0.6594
# epoch 1/3, step 46/65, train_loss=0.6565
# epoch 1/3, step 47/65, train_loss=0.6561
# epoch 1/3, step 48/65, train_loss=0.6550
# epoch 1/3, step 49/65, train_loss=0.6527
# epoch 1/3, step 50/65, train_loss=0.6513
# epoch 1/3, step 51/65, train_loss=0.6487
# epoch 1/3, step 52/65, train_loss=0.6477
# epoch 1/3, step 53/65, train_loss=0.6458
# epoch 1/3, step 54/65, train_loss=0.6437
# epoch 1/3, step 55/65, train_loss=0.6421
# epoch 1/3, step 56/65, train_loss=0.6409
# epoch 1/3, step 57/65, train_loss=0.6409
# epoch 1/3, step 58/65, train_loss=0.6390
# epoch 1/3, step 59/65, train_loss=0.6375
# epoch 1/3, step 60/65, train_loss=0.6364
# epoch 1/3, step 61/65, train_loss=0.6326
# epoch 1/3, step 62/65, train_loss=0.6323
# epoch 1/3, step 63/65, train_loss=0.6332
# epoch 1/3, step 64/65, train_loss=0.6340
# epoch 1/3, step 65/65, train_loss=0.6328
# epoch 1/3, step 1/17, valid_loss=0.4951
# epoch 1/3, step 2/17, valid_loss=0.7449
# epoch 1/3, step 3/17, valid_loss=0.5394
# epoch 1/3, step 4/17, valid_loss=0.4624
# epoch 1/3, step 5/17, valid_loss=0.5970
# epoch 1/3, step 6/17, valid_loss=0.5796
# epoch 1/3, step 7/17, valid_loss=0.7563
# epoch 1/3, step 8/17, valid_loss=0.3214
# epoch 1/3, step 9/17, valid_loss=0.8257
# epoch 1/3, step 10/17, valid_loss=0.2688
# epoch 1/3, step 11/17, valid_loss=0.4770
# epoch 1/3, step 12/17, valid_loss=0.4682
# epoch 1/3, step 13/17, valid_loss=0.4794
# epoch 1/3, step 14/17, valid_loss=0.7115
# epoch 1/3, step 15/17, valid_loss=0.6355
# epoch 1/3, step 16/17, valid_loss=0.5980
# epoch 1/3, step 17/17, valid_loss=0.2587
# epoch 2/3, step 1/65, train_loss=0.4735
# epoch 2/3, step 2/65, train_loss=0.4808
# epoch 2/3, step 3/65, train_loss=0.4557
# epoch 2/3, step 4/65, train_loss=0.4437
# epoch 2/3, step 5/65, train_loss=0.5142
# epoch 2/3, step 6/65, train_loss=0.5088
# epoch 2/3, step 7/65, train_loss=0.5140
# epoch 2/3, step 8/65, train_loss=0.5196
# epoch 2/3, step 9/65, train_loss=0.5500
# epoch 2/3, step 10/65, train_loss=0.5506
# epoch 2/3, step 11/65, train_loss=0.5458
# epoch 2/3, step 12/65, train_loss=0.5521
# epoch 2/3, step 13/65, train_loss=0.5564
# epoch 2/3, step 14/65, train_loss=0.5556
# epoch 2/3, step 15/65, train_loss=0.5521
# epoch 2/3, step 16/65, train_loss=0.5469
# epoch 2/3, step 17/65, train_loss=0.5444
# epoch 2/3, step 18/65, train_loss=0.5447
# epoch 2/3, step 19/65, train_loss=0.5415
# epoch 2/3, step 20/65, train_loss=0.5477
# epoch 2/3, step 21/65, train_loss=0.5402
# epoch 2/3, step 22/65, train_loss=0.5360
# epoch 2/3, step 23/65, train_loss=0.5352
# epoch 2/3, step 24/65, train_loss=0.5281
# epoch 2/3, step 25/65, train_loss=0.5263
# epoch 2/3, step 26/65, train_loss=0.5255
# epoch 2/3, step 27/65, train_loss=0.5187
# epoch 2/3, step 28/65, train_loss=0.5181
# epoch 2/3, step 29/65, train_loss=0.5136
# epoch 2/3, step 30/65, train_loss=0.5111
# epoch 2/3, step 31/65, train_loss=0.5064
# epoch 2/3, step 32/65, train_loss=0.5005
# epoch 2/3, step 33/65, train_loss=0.4967
# epoch 2/3, step 34/65, train_loss=0.4947
# epoch 2/3, step 35/65, train_loss=0.4952
# epoch 2/3, step 36/65, train_loss=0.4985
# epoch 2/3, step 37/65, train_loss=0.5013
# epoch 2/3, step 38/65, train_loss=0.4998
# epoch 2/3, step 39/65, train_loss=0.4931
# epoch 2/3, step 40/65, train_loss=0.4913
# epoch 2/3, step 41/65, train_loss=0.4919
# epoch 2/3, step 42/65, train_loss=0.4893
# epoch 2/3, step 43/65, train_loss=0.4951
# epoch 2/3, step 44/65, train_loss=0.4884
# epoch 2/3, step 45/65, train_loss=0.4824
# epoch 2/3, step 46/65, train_loss=0.4779
# epoch 2/3, step 47/65, train_loss=0.4723
# epoch 2/3, step 48/65, train_loss=0.4687
# epoch 2/3, step 49/65, train_loss=0.4690
# epoch 2/3, step 50/65, train_loss=0.4691
# epoch 2/3, step 51/65, train_loss=0.4679
# epoch 2/3, step 52/65, train_loss=0.4704
# epoch 2/3, step 53/65, train_loss=0.4681
# epoch 2/3, step 54/65, train_loss=0.4648
# epoch 2/3, step 55/65, train_loss=0.4687
# epoch 2/3, step 56/65, train_loss=0.4752
# epoch 2/3, step 57/65, train_loss=0.4760
# epoch 2/3, step 58/65, train_loss=0.4754
# epoch 2/3, step 59/65, train_loss=0.4772
# epoch 2/3, step 60/65, train_loss=0.4768
# epoch 2/3, step 61/65, train_loss=0.4728
# epoch 2/3, step 62/65, train_loss=0.4702
# epoch 2/3, step 63/65, train_loss=0.4696
# epoch 2/3, step 64/65, train_loss=0.4665
# epoch 2/3, step 65/65, train_loss=0.4694
# epoch 2/3, step 1/17, valid_loss=0.6518
# epoch 2/3, step 2/17, valid_loss=0.3299
# epoch 2/3, step 3/17, valid_loss=0.3967
# epoch 2/3, step 4/17, valid_loss=0.5380
# epoch 2/3, step 5/17, valid_loss=0.4911
# epoch 2/3, step 6/17, valid_loss=0.4500
# epoch 2/3, step 7/17, valid_loss=0.7089
# epoch 2/3, step 8/17, valid_loss=0.2622
# epoch 2/3, step 9/17, valid_loss=0.5008
# epoch 2/3, step 10/17, valid_loss=0.4107
# epoch 2/3, step 11/17, valid_loss=0.3259
# epoch 2/3, step 12/17, valid_loss=0.6056
# epoch 2/3, step 13/17, valid_loss=0.4880
# epoch 2/3, step 14/17, valid_loss=0.6355
# epoch 2/3, step 15/17, valid_loss=0.6130
# epoch 2/3, step 16/17, valid_loss=0.5389
# epoch 2/3, step 17/17, valid_loss=0.0877
# epoch 3/3, step 1/65, train_loss=0.4787
# epoch 3/3, step 2/65, train_loss=0.3912
# epoch 3/3, step 3/65, train_loss=0.4041
# epoch 3/3, step 4/65, train_loss=0.3938
# epoch 3/3, step 5/65, train_loss=0.3883
# epoch 3/3, step 6/65, train_loss=0.3921
# epoch 3/3, step 7/65, train_loss=0.3762
# epoch 3/3, step 8/65, train_loss=0.3769
# epoch 3/3, step 9/65, train_loss=0.3614
# epoch 3/3, step 10/65, train_loss=0.3470
# epoch 3/3, step 11/65, train_loss=0.3380
# epoch 3/3, step 12/65, train_loss=0.3443
# epoch 3/3, step 13/65, train_loss=0.3458
# epoch 3/3, step 14/65, train_loss=0.3472
# epoch 3/3, step 15/65, train_loss=0.3393
# epoch 3/3, step 16/65, train_loss=0.3303
# epoch 3/3, step 17/65, train_loss=0.3187
# epoch 3/3, step 18/65, train_loss=0.3315
# epoch 3/3, step 19/65, train_loss=0.3190
# epoch 3/3, step 20/65, train_loss=0.3183
# epoch 3/3, step 21/65, train_loss=0.3084
# epoch 3/3, step 22/65, train_loss=0.3096
# epoch 3/3, step 23/65, train_loss=0.3118
# epoch 3/3, step 24/65, train_loss=0.3036
# epoch 3/3, step 25/65, train_loss=0.2947
# epoch 3/3, step 26/65, train_loss=0.2908
# epoch 3/3, step 27/65, train_loss=0.3017
# epoch 3/3, step 28/65, train_loss=0.2989
# epoch 3/3, step 29/65, train_loss=0.3000
# epoch 3/3, step 30/65, train_loss=0.2975
# epoch 3/3, step 31/65, train_loss=0.3027
# epoch 3/3, step 32/65, train_loss=0.3019
# epoch 3/3, step 33/65, train_loss=0.2995
# epoch 3/3, step 34/65, train_loss=0.2936
# epoch 3/3, step 35/65, train_loss=0.2946
# epoch 3/3, step 36/65, train_loss=0.2989
# epoch 3/3, step 37/65, train_loss=0.3020
# epoch 3/3, step 38/65, train_loss=0.3019
# epoch 3/3, step 39/65, train_loss=0.2958
# epoch 3/3, step 40/65, train_loss=0.2990
# epoch 3/3, step 41/65, train_loss=0.3030
# epoch 3/3, step 42/65, train_loss=0.3090
# epoch 3/3, step 43/65, train_loss=0.3039
# epoch 3/3, step 44/65, train_loss=0.3064
# epoch 3/3, step 45/65, train_loss=0.3021
# epoch 3/3, step 46/65, train_loss=0.3078
# epoch 3/3, step 47/65, train_loss=0.3144
# epoch 3/3, step 48/65, train_loss=0.3119
# epoch 3/3, step 49/65, train_loss=0.3096
# epoch 3/3, step 50/65, train_loss=0.3082
# epoch 3/3, step 51/65, train_loss=0.3074
# epoch 3/3, step 52/65, train_loss=0.3060
# epoch 3/3, step 53/65, train_loss=0.3070
# epoch 3/3, step 54/65, train_loss=0.3052
# epoch 3/3, step 55/65, train_loss=0.3030
# epoch 3/3, step 56/65, train_loss=0.3004
# epoch 3/3, step 57/65, train_loss=0.3007
# epoch 3/3, step 58/65, train_loss=0.2983
# epoch 3/3, step 59/65, train_loss=0.3010
# epoch 3/3, step 60/65, train_loss=0.3028
# epoch 3/3, step 61/65, train_loss=0.3016
# epoch 3/3, step 62/65, train_loss=0.2995
# epoch 3/3, step 63/65, train_loss=0.2985
# epoch 3/3, step 64/65, train_loss=0.3001
# epoch 3/3, step 65/65, train_loss=0.2989
# epoch 3/3, step 1/17, valid_loss=0.5595
# epoch 3/3, step 2/17, valid_loss=0.3479
# epoch 3/3, step 3/17, valid_loss=0.4152
# epoch 3/3, step 4/17, valid_loss=0.7333
# epoch 3/3, step 5/17, valid_loss=0.4135
# epoch 3/3, step 6/17, valid_loss=0.3901
# epoch 3/3, step 7/17, valid_loss=0.8050
# epoch 3/3, step 8/17, valid_loss=0.2317
# epoch 3/3, step 9/17, valid_loss=0.5335
# epoch 3/3, step 10/17, valid_loss=0.2253
# epoch 3/3, step 11/17, valid_loss=0.2264
# epoch 3/3, step 12/17, valid_loss=0.5366
# epoch 3/3, step 13/17, valid_loss=0.3782
# epoch 3/3, step 14/17, valid_loss=0.7172
# epoch 3/3, step 15/17, valid_loss=0.4727
# epoch 3/3, step 16/17, valid_loss=0.4308
# epoch 3/3, step 17/17, valid_loss=0.0393
# [0.6643811698704651, 0.5015591688026194, 0.3208528410271841]
# [1, 2, 3]

# %% [markdown]
# # Testing

# %%
def testing(model, test_data):
  metrics_0 = {}
  metrics_1 = {}
  test_len = test_data.shape[0]
  text_test = test_data["Text"]
  targets_test = test_data[target_list].to_numpy().reshape(-1,2)
  targets_pred = []

  model.eval()
  with torch.no_grad():
    for review in text_test:
        review = str(review)
        emb = b_tokenizer.encode_plus(review,
                                      None,
                                      add_special_tokens=True,
                                      max_length=MAX_LEN,
                                      padding="max_length",
                                      truncation=True,
                                      return_attention_mask=True,
                                      return_tensors="pt"
                                      )

        input_ids = emb["input_ids"].to(device, dtype=torch.long)
        attention_mask = emb['attention_mask'].to(device, dtype=torch.long)
        token_type_ids = emb['token_type_ids'].to(device, dtype=torch.long)

        res = model(input_ids, attention_mask, token_type_ids)
        final_res = torch.sigmoid(res).cpu().detach().numpy()

        targets_pred.append(final_res)

    targets_pred = np.array(targets_pred).reshape(-1,2)
    targets_pred = np.apply_along_axis(max_class, 1, targets_pred)

    metrics_0["accuracy_score"] = accuracy_score(targets_test[:, 0], targets_pred[:, 0])
    metrics_0["precision_score"] =  precision_score(targets_test[:, 0], targets_pred[:, 0])
    metrics_0["recall_score"] = recall_score(targets_test[:, 0], targets_pred[:, 0])
    metrics_0["f1_score"] =  f1_score(targets_test[:, 0], targets_pred[:, 0])

    metrics_1["accuracy_score"] = accuracy_score(targets_test[:, 1], targets_pred[:, 1])
    metrics_1["precision_score"] =  precision_score(targets_test[:, 1], targets_pred[:, 1])
    metrics_1["recall_score"] = recall_score(targets_test[:, 1], targets_pred[:, 1])
    metrics_1["f1_score"] =  f1_score(targets_test[:, 1], targets_pred[:, 1])

    confusion_matrix_0 = confusion_matrix(targets_test[:, 0], targets_pred[:, 0])
    confusion_matrix_1 = confusion_matrix(targets_test[:, 1], targets_pred[:, 1])

    cm_display = ConfusionMatrixDisplay(
        confusion_matrix=confusion_matrix_0,
        display_labels=[0, 1])

    print(f"metrics_0: {metrics_0}\n metrics_1: {metrics_1}")
    print(classification_report(targets_test[:, 0], targets_pred[:, 0], target_names=['Truthful', 'Fake']))
    cm_display.plot()
    plt.show()

# %%
def max_class(item):
  item = np.where(item == max(item), 1, 0)
  return item

# %%
testing(trained_model, test_data)
# Out:
# metrics_0: {'accuracy_score': 0.8171296296296297, 'precision_score': 0.8685714285714285, 'recall_score': 0.7307692307692307, 'f1_score': 0.793733681462141}
#  metrics_1: {'accuracy_score': 0.8171296296296297, 'precision_score': 0.7821011673151751, 'recall_score': 0.8973214285714286, 'f1_score': 0.8357588357588358}
#               precision    recall  f1-score   support
#
#     Truthful       0.78      0.90      0.84       224
#         Fake       0.87      0.73      0.79       208
#
#     accuracy                           0.82       432
#    macro avg       0.83      0.81      0.81       432
# weighted avg       0.82      0.82      0.82       432

# %% [markdown]
# # Exite

# %%
exit()

# %% [markdown]
# # Preprotion

# %%
import shutil
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import train_test_split
import transformers
from sklearn.metrics import precision_score, recall_score, f1_score,\
 accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# data path
data_paths = {}
data_paths["H"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Hotel.xlsx' # hotel
data_paths["R"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Resturent.xlsx' # resturent
data_paths["P"] = '/content/drive/MyDrive/Data/AFRD/All_Dataset/Prodect.xlsx' # prodect

target_list = ['Fake', 'Truthful']

# %%
b_tokenizer = transformers.AutoTokenizer.from_pretrained("/content/drive/MyDrive/Models/tokenizers-bert-base-arabertv2")

# %%
MAX_LEN = 265
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
EPOCHS = 3
LEARNING_RATE = 2.5e-05

# %% [markdown]
# # Build the Model

# %%
class AFRD(Dataset):
    def __init__(self, dataset, tokenizer, max_len):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.text = self.dataset["Text"]
        self.targets = self.dataset[target_list].values
        self.n_samples = self.dataset.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        review = str(self.text[index])
        review = " ".join(review.split())

        inputs = self.tokenizer.encode_plus(review,
                                            None,
                                            add_special_tokens=True,
                                            max_length=self.max_len,
                                            padding="max_length",
                                            truncation=True,
                                            return_attention_mask=True,
                                            return_tensors="pt"
                                            )

        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "token_type_ids": inputs["token_type_ids"].flatten(),
            "targets": torch.FloatTensor(np.array(self.targets[index])).flatten()
        }

# %%
class BERTClass(nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.bert_model = transformers.AutoModel.from_pretrained("/content/drive/MyDrive/Models/model-bert-base-arabertv2", return_dict=True)
        self.linear1 = nn.Linear(768, 256)
        self.linear2 = nn.Linear(256, 2)


    def forward(self, input_ids, attention_mask, token_type_ids):
        output = self.bert_model(input_ids, attention_mask, token_type_ids)
        output = self.linear1(output["pooler_output"])
        output = self.linear2(output)

        return output

# %%
model = BERTClass()
model.to(device)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /content/drive/MyDrive/Models/model-bert-base-arabertv2 and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTClass(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (linear1): Linear(in_features=768, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=2, bias=True)
# )

# %% [markdown]
# # saving & loadding Function

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']

    return model, optimizer, checkpoint['epoch'], valid_loss_min.item()

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %% [markdown]
# # Loss Function & Optimizer

# %%
def loss_fn(output, target):
    return nn.BCEWithLogitsLoss()(output, target)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Training Function

# %%
def train_model(
        n_epochs,
        training_loader,
        validation_loader,
        model,
        optimizer,
        checkpoint_path,
        best_model_path
):
    train_loss_list = []
    valid_loss_list = []

    n_total_steps_train = len(training_loader)
    n_total_steps_valid = len(validation_loader)

    valid_loss_min = np.Inf

    for epoch in range(n_epochs):

        sum_train_loss = 0
        sum_valid_loss = 0
        train_loss = 0
        valid_loss = 0
        model.train()
        # train

        for index, batch in enumerate(training_loader):
            input_ids = batch["input_ids"].to(device, dtype=torch.long)
            attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
            targets = batch['targets'].to(device, dtype=torch.float)


            # forward pass
            output = model(input_ids, attention_mask, token_type_ids)

            optimizer.zero_grad()
            loss = loss_fn(output, targets)
            optimizer.zero_grad()

            # backward pass
            loss.backward()
            optimizer.step()

            train_loss = train_loss + (1/(index+1)*(loss.item()-train_loss))
            sum_train_loss += train_loss
            print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_train}, train_loss={train_loss:.4f}")
            # optimizer.zero_grad()

        # valid
        model.eval()
        with torch.no_grad():
            for index, batch in enumerate(validation_loader):
                input_ids = batch["input_ids"].to(device, dtype=torch.long)
                attention_mask = batch['attention_mask'].to(device, dtype=torch.long)
                token_type_ids = batch['token_type_ids'].to(device, dtype=torch.long)
                targets = batch['targets'].to(device, dtype=torch.float)
                output = model(input_ids, attention_mask, token_type_ids)

                loss = loss_fn(output, targets)
                valid_loss = valid_loss + (1 / (index + 1) * (loss.item() - valid_loss))
                sum_valid_loss += valid_loss
                print(f"epoch {epoch + 1}/{n_epochs}, step {index + 1}/{n_total_steps_valid}, valid_loss={loss.item():.4f}")

        checkpoint = {
            "epoch": epoch + 1,
            "valid_loss_min": valid_loss,
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict()
        }

        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        train_loss_list.append(sum_train_loss/n_total_steps_train)
        valid_loss_list.append(sum_valid_loss/n_total_steps_valid)
    # Train & Valid loss Curve
    # Generate a sequence of integers to represent the epoch numbers
    epochs_r = list(range(1, n_epochs+1))
    print(train_loss_list)
    print(epochs_r)

    # Plot and label the training and validation loss values
    plt.plot(epochs_r, train_loss_list, label='Training Loss')
    plt.plot(epochs_r, valid_loss_list, label='Validation Loss')

    # Add in a title and axes labels
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Set the tick locations
    plt.xticks(range(1, n_epochs+1, 1))

    # Display the plot
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# # Test Function

# %%
def test_model(model, test_data):
  metrics_0 = {}
  metrics_1 = {}
  test_len = test_data.shape[0]
  text_test = test_data["Text"]
  targets_test = test_data[target_list].to_numpy().reshape(-1,2)
  del test_data
  targets_pred = []

  model.eval()
  with torch.no_grad():
    for review in text_test:
        review = str(review)
        emb = b_tokenizer.encode_plus(review,
                                      None,
                                      add_special_tokens=True,
                                      max_length=MAX_LEN,
                                      padding="max_length",
                                      truncation=True,
                                      return_attention_mask=True,
                                      return_tensors="pt"
                                      )

        input_ids = emb["input_ids"].to(device, dtype=torch.long)
        attention_mask = emb['attention_mask'].to(device, dtype=torch.long)
        token_type_ids = emb['token_type_ids'].to(device, dtype=torch.long)

        res = model(input_ids, attention_mask, token_type_ids)
        final_res = torch.sigmoid(res).cpu().detach().numpy()

        targets_pred.append(final_res)

  targets_pred = np.array(targets_pred).reshape(-1,2)
  targets_pred = np.apply_along_axis(max_class, 1, targets_pred)

  metrics_0["accuracy_score"] = accuracy_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["precision_score"] =  precision_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["recall_score"] = recall_score(targets_test[:, 0], targets_pred[:, 0])
  metrics_0["f1_score"] =  f1_score(targets_test[:, 0], targets_pred[:, 0])

  metrics_1["accuracy_score"] = accuracy_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["precision_score"] =  precision_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["recall_score"] = recall_score(targets_test[:, 1], targets_pred[:, 1])
  metrics_1["f1_score"] =  f1_score(targets_test[:, 1], targets_pred[:, 1])

  confusion_matrix_res = confusion_matrix(targets_test[:, 0], targets_pred[:, 0])

  cm_display = ConfusionMatrixDisplay(
      confusion_matrix=confusion_matrix_res,
      display_labels=[0, 1])

  print(f"metrics_0: {metrics_0}\n metrics_1: {metrics_1}")
  print(classification_report(targets_test[:, 0], targets_pred[:, 0], target_names=['Truthful', 'Fake']))
  cm_display.plot()
  plt.show()

# %%
def max_class(item):
  item = np.where(item == max(item), 1, 0)
  return item

# %% [markdown]
# # Multi data training/Testing

# %%
def pipeline(data_paths, model, optimizer, train_fn, test_fn):
  curr_stage = ''
  total_test = pd.DataFrame(columns=['Text', 'Fake', 'Truthful'])
  exe_seq = ["R", "P", "H"]
  for i in exe_seq:
    # import the data set
    data = pd.read_excel(data_paths[i])
    data.drop(labels=['Age', 'Gender','Platform/Name', 'Product', 'Rating', 'Polarity'], axis=1, inplace=True)
    target_list = ['Fake', 'Truthful']

    # encoding
    enc_y_data = pd.get_dummies(data['Class'], dtype=float)
    data[target_list] = enc_y_data[target_list]
    data.drop(labels=['Class'], axis=1, inplace=True)

    # splitting the data into train, valid, test
    train_data, test_data = train_test_split(data, test_size=0.25, random_state=32, shuffle=True)
    train_data, valid_data = train_test_split(train_data, test_size=0.2, random_state=32, shuffle=True,)

    train_data.reset_index(drop=True, inplace=True)
    valid_data.reset_index(drop=True, inplace=True)
    test_data.reset_index(drop=True, inplace=True)

    train_data = AFRD(train_data, b_tokenizer, MAX_LEN)
    valid_data = AFRD(valid_data, b_tokenizer, MAX_LEN)

    train_data_loader = DataLoader(
    train_data,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
    num_workers=0
    )

    val_data_loader = DataLoader(
    valid_data,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=0
    )
    del train_data, valid_data

    curr_stage = curr_stage + f"{i}"
    print(f'############################-{curr_stage}model-################################')
    # Training
    train_fn(EPOCHS, train_data_loader, val_data_loader, model, optimizer, f"./{curr_stage}_curr_ck.pt", f"./{curr_stage}_best.pt")
    # Testing
    test_fn(model, test_data)

    del train_data_loader, val_data_loader
    total_test = pd.concat([total_test, test_data], ignore_index=True)
    del test_data

  print('###############################-Final Test-#######################################')
  test_fn(model, total_test)

# %%
pipeline(data_paths, model, optimizer, train_model, test_model)
# Out:
# ############################-Rmodel-################################
# epoch 1/3, step 1/27, train_loss=0.6929
# epoch 1/3, step 2/27, train_loss=0.6954
# epoch 1/3, step 3/27, train_loss=0.6946
# epoch 1/3, step 4/27, train_loss=0.6922
# epoch 1/3, step 5/27, train_loss=0.6928
# epoch 1/3, step 6/27, train_loss=0.6874
# epoch 1/3, step 7/27, train_loss=0.6856
# epoch 1/3, step 8/27, train_loss=0.6804
# epoch 1/3, step 9/27, train_loss=0.6783
# epoch 1/3, step 10/27, train_loss=0.6820
# epoch 1/3, step 11/27, train_loss=0.6777
# epoch 1/3, step 12/27, train_loss=0.6765
# epoch 1/3, step 13/27, train_loss=0.6748
# epoch 1/3, step 14/27, train_loss=0.6733
# epoch 1/3, step 15/27, train_loss=0.6702
# epoch 1/3, step 16/27, train_loss=0.6659
# epoch 1/3, step 17/27, train_loss=0.6611
# epoch 1/3, step 18/27, train_loss=0.6587
# epoch 1/3, step 19/27, train_loss=0.6568
# epoch 1/3, step 20/27, train_loss=0.6554
# epoch 1/3, step 21/27, train_loss=0.6536
# epoch 1/3, step 22/27, train_loss=0.6550
# epoch 1/3, step 23/27, train_loss=0.6518
# epoch 1/3, step 24/27, train_loss=0.6499
# epoch 1/3, step 25/27, train_loss=0.6453
# epoch 1/3, step 26/27, train_loss=0.6422
# epoch 1/3, step 27/27, train_loss=0.6381
# epoch 1/3, step 1/7, valid_loss=0.5844
# epoch 1/3, step 2/7, valid_loss=0.5647
# epoch 1/3, step 3/7, valid_loss=0.6514
# epoch 1/3, step 4/7, valid_loss=0.6546
# epoch 1/3, step 5/7, valid_loss=0.5925
# epoch 1/3, step 6/7, valid_loss=0.7514
# epoch 1/3, step 7/7, valid_loss=0.6134
# epoch 2/3, step 1/27, train_loss=0.5894
# epoch 2/3, step 2/27, train_loss=0.5369
# epoch 2/3, step 3/27, train_loss=0.5543
# epoch 2/3, step 4/27, train_loss=0.5753
# epoch 2/3, step 5/27, train_loss=0.5540
# epoch 2/3, step 6/27, train_loss=0.5531
# epoch 2/3, step 7/27, train_loss=0.5309
# epoch 2/3, step 8/27, train_loss=0.5403
# epoch 2/3, step 9/27, train_loss=0.5227
# epoch 2/3, step 10/27, train_loss=0.5256
# epoch 2/3, step 11/27, train_loss=0.5283
# epoch 2/3, step 12/27, train_loss=0.5266
# epoch 2/3, step 13/27, train_loss=0.5199
# epoch 2/3, step 14/27, train_loss=0.5159
# epoch 2/3, step 15/27, train_loss=0.5229
# epoch 2/3, step 16/27, train_loss=0.5141
# epoch 2/3, step 17/27, train_loss=0.5127
# epoch 2/3, step 18/27, train_loss=0.5100
# epoch 2/3, step 19/27, train_loss=0.5060
# epoch 2/3, step 20/27, train_loss=0.5078
# epoch 2/3, step 21/27, train_loss=0.5022
# epoch 2/3, step 22/27, train_loss=0.4999
# epoch 2/3, step 23/27, train_loss=0.5027
# epoch 2/3, step 24/27, train_loss=0.5043
# epoch 2/3, step 25/27, train_loss=0.5060
# epoch 2/3, step 26/27, train_loss=0.5075
# epoch 2/3, step 27/27, train_loss=0.5134
# epoch 2/3, step 1/7, valid_loss=0.3645
# epoch 2/3, step 2/7, valid_loss=0.4164
# epoch 2/3, step 3/7, valid_loss=0.3614
# epoch 2/3, step 4/7, valid_loss=0.3386
# epoch 2/3, step 5/7, valid_loss=0.5097
# epoch 2/3, step 6/7, valid_loss=0.6638
# epoch 2/3, step 7/7, valid_loss=0.4320
# epoch 3/3, step 1/27, train_loss=0.2889
# epoch 3/3, step 2/27, train_loss=0.3671
# epoch 3/3, step 3/27, train_loss=0.3710
# epoch 3/3, step 4/27, train_loss=0.3465
# epoch 3/3, step 5/27, train_loss=0.3439
# epoch 3/3, step 6/27, train_loss=0.3415
# epoch 3/3, step 7/27, train_loss=0.3318
# epoch 3/3, step 8/27, train_loss=0.3342
# epoch 3/3, step 9/27, train_loss=0.3494
# epoch 3/3, step 10/27, train_loss=0.3556
# epoch 3/3, step 11/27, train_loss=0.3473
# epoch 3/3, step 12/27, train_loss=0.3419
# epoch 3/3, step 13/27, train_loss=0.3284
# epoch 3/3, step 14/27, train_loss=0.3207
# epoch 3/3, step 15/27, train_loss=0.3268
# epoch 3/3, step 16/27, train_loss=0.3206
# epoch 3/3, step 17/27, train_loss=0.3352
# epoch 3/3, step 18/27, train_loss=0.3411
# epoch 3/3, step 19/27, train_loss=0.3395
# epoch 3/3, step 20/27, train_loss=0.3398
# epoch 3/3, step 21/27, train_loss=0.3424
# epoch 3/3, step 22/27, train_loss=0.3361
# epoch 3/3, step 23/27, train_loss=0.3453
# epoch 3/3, step 24/27, train_loss=0.3377
# epoch 3/3, step 25/27, train_loss=0.3365
# epoch 3/3, step 26/27, train_loss=0.3421
# epoch 3/3, step 27/27, train_loss=0.3447
# epoch 3/3, step 1/7, valid_loss=0.2959
# epoch 3/3, step 2/7, valid_loss=0.5635
# epoch 3/3, step 3/7, valid_loss=0.6520
# epoch 3/3, step 4/7, valid_loss=0.3428
# epoch 3/3, step 5/7, valid_loss=0.4108
# epoch 3/3, step 6/7, valid_loss=1.1177
# epoch 3/3, step 7/7, valid_loss=0.5735
# [0.6699223295221364, 0.5252784627870921, 0.3391154370087151]
# [1, 2, 3]
# metrics_0: {'accuracy_score': 0.776536312849162, 'precision_score': 0.8888888888888888, 'recall_score': 0.6666666666666666, 'f1_score': 0.761904761904762}
#  metrics_1: {'accuracy_score': 0.776536312849162, 'precision_score': 0.7009345794392523, 'recall_score': 0.9036144578313253, 'f1_score': 0.7894736842105263}
#               precision    recall  f1-score   support
#
#     Truthful       0.70      0.90      0.79        83
#         Fake       0.89      0.67      0.76        96
#
#     accuracy                           0.78       179
#    macro avg       0.79      0.79      0.78       179
# weighted avg       0.80      0.78      0.77       179
# ############################-RPmodel-################################
# epoch 1/3, step 1/27, train_loss=0.7629
# epoch 1/3, step 2/27, train_loss=0.4967
# epoch 1/3, step 3/27, train_loss=0.5317
# epoch 1/3, step 4/27, train_loss=0.5860
# epoch 1/3, step 5/27, train_loss=0.5948
# epoch 1/3, step 6/27, train_loss=0.5961
# epoch 1/3, step 7/27, train_loss=0.5736
# epoch 1/3, step 8/27, train_loss=0.5956
# epoch 1/3, step 9/27, train_loss=0.6006
# epoch 1/3, step 10/27, train_loss=0.6092
# epoch 1/3, step 11/27, train_loss=0.6085
# epoch 1/3, step 12/27, train_loss=0.5962
# epoch 1/3, step 13/27, train_loss=0.5907
# epoch 1/3, step 14/27, train_loss=0.5866
# epoch 1/3, step 15/27, train_loss=0.5794
# epoch 1/3, step 16/27, train_loss=0.5788
# epoch 1/3, step 17/27, train_loss=0.5858
# epoch 1/3, step 18/27, train_loss=0.5827
# epoch 1/3, step 19/27, train_loss=0.5778
# epoch 1/3, step 20/27, train_loss=0.5898
# epoch 1/3, step 21/27, train_loss=0.5891
# epoch 1/3, step 22/27, train_loss=0.5774
# epoch 1/3, step 23/27, train_loss=0.5679
# epoch 1/3, step 24/27, train_loss=0.5683
# epoch 1/3, step 25/27, train_loss=0.5616
# epoch 1/3, step 26/27, train_loss=0.5634
# epoch 1/3, step 27/27, train_loss=0.5705
# epoch 1/3, step 1/7, valid_loss=0.6482
# epoch 1/3, step 2/7, valid_loss=0.6182
# epoch 1/3, step 3/7, valid_loss=0.3499
# epoch 1/3, step 4/7, valid_loss=0.6278
# epoch 1/3, step 5/7, valid_loss=0.5785
# epoch 1/3, step 6/7, valid_loss=0.4681
# epoch 1/3, step 7/7, valid_loss=0.4004
# epoch 2/3, step 1/27, train_loss=0.4219
# epoch 2/3, step 2/27, train_loss=0.3271
# epoch 2/3, step 3/27, train_loss=0.3194
# epoch 2/3, step 4/27, train_loss=0.3611
# epoch 2/3, step 5/27, train_loss=0.3525
# epoch 2/3, step 6/27, train_loss=0.3690
# epoch 2/3, step 7/27, train_loss=0.3657
# epoch 2/3, step 8/27, train_loss=0.3757
# epoch 2/3, step 9/27, train_loss=0.3924
# epoch 2/3, step 10/27, train_loss=0.3835
# epoch 2/3, step 11/27, train_loss=0.3830
# epoch 2/3, step 12/27, train_loss=0.3955
# epoch 2/3, step 13/27, train_loss=0.3899
# epoch 2/3, step 14/27, train_loss=0.3831
# epoch 2/3, step 15/27, train_loss=0.3700
# epoch 2/3, step 16/27, train_loss=0.3591
# epoch 2/3, step 17/27, train_loss=0.3679
# epoch 2/3, step 18/27, train_loss=0.3686
# epoch 2/3, step 19/27, train_loss=0.3744
# epoch 2/3, step 20/27, train_loss=0.3664
# epoch 2/3, step 21/27, train_loss=0.3700
# epoch 2/3, step 22/27, train_loss=0.3799
# epoch 2/3, step 23/27, train_loss=0.3757
# epoch 2/3, step 24/27, train_loss=0.3662
# epoch 2/3, step 25/27, train_loss=0.3621
# epoch 2/3, step 26/27, train_loss=0.3565
# epoch 2/3, step 27/27, train_loss=0.3629
# epoch 2/3, step 1/7, valid_loss=0.5574
# epoch 2/3, step 2/7, valid_loss=0.6039
# epoch 2/3, step 3/7, valid_loss=0.3657
# epoch 2/3, step 4/7, valid_loss=0.5905
# epoch 2/3, step 5/7, valid_loss=0.7748
# epoch 2/3, step 6/7, valid_loss=0.4962
# epoch 2/3, step 7/7, valid_loss=0.1496
# epoch 3/3, step 1/27, train_loss=0.1931
# epoch 3/3, step 2/27, train_loss=0.3579
# epoch 3/3, step 3/27, train_loss=0.3505
# epoch 3/3, step 4/27, train_loss=0.3415
# epoch 3/3, step 5/27, train_loss=0.3478
# epoch 3/3, step 6/27, train_loss=0.3047
# epoch 3/3, step 7/27, train_loss=0.2975
# epoch 3/3, step 8/27, train_loss=0.2766
# epoch 3/3, step 9/27, train_loss=0.2789
# epoch 3/3, step 10/27, train_loss=0.2816
# epoch 3/3, step 11/27, train_loss=0.3034
# epoch 3/3, step 12/27, train_loss=0.2862
# epoch 3/3, step 13/27, train_loss=0.2830
# epoch 3/3, step 14/27, train_loss=0.2997
# epoch 3/3, step 15/27, train_loss=0.2899
# epoch 3/3, step 16/27, train_loss=0.2937
# epoch 3/3, step 17/27, train_loss=0.2815
# epoch 3/3, step 18/27, train_loss=0.2850
# epoch 3/3, step 19/27, train_loss=0.2882
# epoch 3/3, step 20/27, train_loss=0.3056
# epoch 3/3, step 21/27, train_loss=0.2999
# epoch 3/3, step 22/27, train_loss=0.2910
# epoch 3/3, step 23/27, train_loss=0.2876
# epoch 3/3, step 24/27, train_loss=0.2872
# epoch 3/3, step 25/27, train_loss=0.2961
# epoch 3/3, step 26/27, train_loss=0.2883
# epoch 3/3, step 27/27, train_loss=0.2824
# epoch 3/3, step 1/7, valid_loss=0.5781
# epoch 3/3, step 2/7, valid_loss=0.6706
# epoch 3/3, step 3/7, valid_loss=0.2397
# epoch 3/3, step 4/7, valid_loss=0.6855
# epoch 3/3, step 5/7, valid_loss=0.5459
# epoch 3/3, step 6/7, valid_loss=0.4035
# epoch 3/3, step 7/7, valid_loss=0.1381
# [0.5859788375619616, 0.37035359808703094, 0.2955077912492962]
# [1, 2, 3]
# metrics_0: {'accuracy_score': 0.7954545454545454, 'precision_score': 0.8181818181818182, 'recall_score': 0.782608695652174, 'f1_score': 0.8}
#  metrics_1: {'accuracy_score': 0.7954545454545454, 'precision_score': 0.7727272727272727, 'recall_score': 0.8095238095238095, 'f1_score': 0.7906976744186046}
#               precision    recall  f1-score   support
#
#     Truthful       0.77      0.81      0.79        84
#         Fake       0.82      0.78      0.80        92
#
#     accuracy                           0.80       176
#    macro avg       0.80      0.80      0.80       176
# weighted avg       0.80      0.80      0.80       176
# ############################-RPHmodel-################################
# epoch 1/3, step 1/12, train_loss=0.1412
# epoch 1/3, step 2/12, train_loss=0.1499
# epoch 1/3, step 3/12, train_loss=0.2397
# epoch 1/3, step 4/12, train_loss=0.3124
# epoch 1/3, step 5/12, train_loss=0.3890
# epoch 1/3, step 6/12, train_loss=0.4444
# epoch 1/3, step 7/12, train_loss=0.3970
# epoch 1/3, step 8/12, train_loss=0.4579
# epoch 1/3, step 9/12, train_loss=0.4741
# epoch 1/3, step 10/12, train_loss=0.4722
# epoch 1/3, step 11/12, train_loss=0.5108
# epoch 1/3, step 12/12, train_loss=0.5250
# epoch 1/3, step 1/3, valid_loss=0.5034
# epoch 1/3, step 2/3, valid_loss=0.4353
# epoch 1/3, step 3/3, valid_loss=0.1301
# epoch 2/3, step 1/12, train_loss=0.3193
# epoch 2/3, step 2/12, train_loss=0.4054
# epoch 2/3, step 3/12, train_loss=0.3812
# epoch 2/3, step 4/12, train_loss=0.4235
# epoch 2/3, step 5/12, train_loss=0.4707
# epoch 2/3, step 6/12, train_loss=0.4413
# epoch 2/3, step 7/12, train_loss=0.4259
# epoch 2/3, step 8/12, train_loss=0.3982
# epoch 2/3, step 9/12, train_loss=0.4081
# epoch 2/3, step 10/12, train_loss=0.4079
# epoch 2/3, step 11/12, train_loss=0.3963
# epoch 2/3, step 12/12, train_loss=0.3962
# epoch 2/3, step 1/3, valid_loss=0.6276
# epoch 2/3, step 2/3, valid_loss=0.5531
# epoch 2/3, step 3/3, valid_loss=0.2091
# epoch 3/3, step 1/12, train_loss=0.3562
# epoch 3/3, step 2/12, train_loss=0.3109
# epoch 3/3, step 3/12, train_loss=0.2942
# epoch 3/3, step 4/12, train_loss=0.2919
# epoch 3/3, step 5/12, train_loss=0.2745
# epoch 3/3, step 6/12, train_loss=0.2589
# epoch 3/3, step 7/12, train_loss=0.2531
# epoch 3/3, step 8/12, train_loss=0.2691
# epoch 3/3, step 9/12, train_loss=0.2705
# epoch 3/3, step 10/12, train_loss=0.2542
# epoch 3/3, step 11/12, train_loss=0.2650
# epoch 3/3, step 12/12, train_loss=0.2490
# epoch 3/3, step 1/3, valid_loss=0.4216
# epoch 3/3, step 2/3, valid_loss=0.4158
# epoch 3/3, step 3/3, valid_loss=0.1090
# [0.37612903340441456, 0.40616949087446946, 0.27897670432152927]
# [1, 2, 3]
# metrics_0: {'accuracy_score': 0.8589743589743589, 'precision_score': 0.7948717948717948, 'recall_score': 0.9117647058823529, 'f1_score': 0.8493150684931507}
#  metrics_1: {'accuracy_score': 0.8589743589743589, 'precision_score': 0.9230769230769231, 'recall_score': 0.8181818181818182, 'f1_score': 0.8674698795180724}
#               precision    recall  f1-score   support
#
#     Truthful       0.92      0.82      0.87        44
#         Fake       0.79      0.91      0.85        34
#
#     accuracy                           0.86        78
#    macro avg       0.86      0.86      0.86        78
# weighted avg       0.87      0.86      0.86        78
# ###############################-Final Test-#######################################
# metrics_0: {'accuracy_score': 0.7990762124711316, 'precision_score': 0.8609625668449198, 'recall_score': 0.7252252252252253, 'f1_score': 0.7872860635696821}
#  metrics_1: {'accuracy_score': 0.7990762124711316, 'precision_score': 0.7520325203252033, 'recall_score': 0.8767772511848341, 'f1_score': 0.8096280087527352}
#               precision    recall  f1-score   support
#
#     Truthful       0.75      0.88      0.81       211
#         Fake       0.86      0.73      0.79       222
#
#     accuracy                           0.80       433
#    macro avg       0.81      0.80      0.80       433
# weighted avg       0.81      0.80      0.80       433

# %% [markdown]
# # Exit

# %%
exit()
